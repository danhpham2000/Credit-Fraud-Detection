# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2 as pg2
# %matplotlib inline

# %%
conn = pg2.connect(database="Credit_Fraud_Database", user="postgres",
                  password="Spring2021")

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM credit_data")

# %%
cur.fetchone()
# Out:
# (0,
#  datetime.datetime(2019, 1, 1, 0, 0, 18),
#  2703186189652095,
#  'fraud_Rippin, Kub and Mann',
#  'misc_net',
#  Decimal('4.97'),
#  'Jennifer',
#  'Banks',
#  'F',
#  '561 Perry Cove',
#  'Moravian Falls',
#  'NC',
#  28654,
#  Decimal('36.078800000000000'),
#  Decimal('-81.178100000000000'),
#  3495,
#  'Psychologist, counselling',
#  datetime.date(1988, 3, 9),
#  '0b242abb623afc578575680df30655b9',
#  1325376018,
#  Decimal('36.011293000000000'),
#  Decimal('-82.048315000000000'),
#  0)

# %%
data = cur.fetchall()

# %%
data
# Out:
# [(1,
#   datetime.datetime(2019, 1, 1, 0, 0, 44),
#   630423337322,
#   'fraud_Heller, Gutmann and Zieme',
#   'grocery_pos',
#   Decimal('107.23'),
#   'Stephanie',
#   'Gill',
#   'F',
#   '43039 Riley Greens Suite 393',
#   'Orient',
#   'WA',
#   99160,
#   Decimal('48.887800000000000'),
#   Decimal('-118.210500000000000'),
#   149,
#   'Special educational needs teacher',
#   datetime.date(1978, 6, 21),
#   '1f76529f8574734946361c461b024d99',
#   1325376044,
#   Decimal('49.159047000000000'),
#   Decimal('-118.186462000000000'),
#   0),
#  (2,
#   datetime.datetime(2019, 1, 1, 0, 0, 51),
#   38859492057661,
#   'fraud_Lind-Buckridge',
#   'entertainment',
#   Decimal('220.11'),
#   'Edward',
#   'Sanchez',
#   'M',
#   '594 White Dale Suite 530',
#   'Malad City',
#   'ID',
#   83252,
#   Decimal('42.180800000000000'),
#   Decimal('-112.262000000000000'),
#   4154,
#   'Nature conservation officer',
#   datetime.date(1962, 1, 19),
#   'a1a22d70485983eac12b5b88dad1cf95',
#   1325376051,
#   Decimal('43.150704000000000'),
#   Decimal('-112.154481000000000'),
#   0),
#  (3,
#   datetime.datetime(2019, 1, 1, 0, 1, 16),
#   3534093764340240,
#   'fraud_Kutch, Hermiston and Farrell',
#   'gas_transport',
#   Decimal('45.00'),
#   'Jeremy',
#   'White',
#   'M',
#   '9443 Cynthia Court Apt. 038',
#   'Boulder',
#   'MT',
#   59632,
#   Decimal('46.230600000000000'),
#   Decimal('-112.113800000000000'),
#   1939,
#   'Patent attorney',
#   datetime.date(1967, 1, 12),
#   '6b849c168bdad6f867558c3793159a81',
#   1325376076,
#   Decimal('47.034331000000000'),
#   Decimal('-112.561071000000000'),
#   0),
#  (4,
#   datetime.datetime(2019, 1, 1, 0, 3, 6),
#   375534208663984,
#   'fraud_Keeling-Crist',
#   'misc_pos',
#   Decimal('41.96'),
#   'Tyler',
#   'Garcia',
#   'M',
#   '408 Bradley Rest',
#   'Doe Hill',
#   'VA',
#   24433,
#   Decimal('38.420700000000000'),
#   Decimal('-79.462900000000000'),
#   99,
#   'Dance movement psychotherapist',
#   datetime.date(1986, 3, 28),
#   'a41d7549acf90789359a9aa5346dcb46',
#   1325376186,
#   Decimal('38.674999000000000'),
#   Decimal('-78.632459000000000'),
#   0),
#  (5,
#   datetime.datetime(2019, 1, 1, 0, 4, 8),
#   4767265376804500,
#   'fraud_Stroman, Hudson and Erdman',
#   'gas_transport',
#   Decimal('94.63'),
#   'Jennifer',
#   'Conner',
#   'F',
#   '4655 David Island',
#   'Dublin',
#   'PA',
#   18917,
#   Decimal('40.375000000000000'),
#   Decimal('-75.204500000000000'),
#   2158,
#   'Transport planner',
#   datetime.date(1961, 6, 19),
#   '189a841a0a8ba03058526bcfe566aab5',
#   1325376248,
#   Decimal('40.653382000000000'),
#   Decimal('-76.152667000000010'),
#   0),
#  (6,
#   datetime.datetime(2019, 1, 1, 0, 4, 42),
#   30074693890476,
#   'fraud_Rowe-Vandervort',
#   'grocery_net',
#   Decimal('44.54'),
#   'Kelsey',
#   'Richards',
#   'F',
#   '889 Sarah Station Suite 624',
#   'Holcomb',
#   'KS',
#   67851,
#   Decimal('37.993100000000000'),
#   Decimal('-100.989300000000000'),
#   2691,
#   'Arboriculturist',
#   datetime.date(1993, 8, 16),
#   '83ec1cc84142af6e2acf10c44949e720',
#   1325376282,
#   Decimal('37.162705000000000'),
#   Decimal('-100.153370000000000'),
#   0),
#  (7,
#   datetime.datetime(2019, 1, 1, 0, 5, 8),
#   6011360759745864,
#   'fraud_Corwin-Collins',
#   'gas_transport',
#   Decimal('71.65'),
#   'Steven',
#   'Williams',
#   'M',
#   '231 Flores Pass Suite 720',
#   'Edinburg',
#   'VA',
#   22824,
#   Decimal('38.843200000000000'),
#   Decimal('-78.600300000000000'),
#   6018,
#   'Designer, multimedia',
#   datetime.date(1947, 8, 21),
#   '6d294ed2cc447d2c71c7171a3d54967c',
#   1325376308,
#   Decimal('38.948089000000000'),
#   Decimal('-78.540296000000000'),
#   0),
#  (8,
#   datetime.datetime(2019, 1, 1, 0, 5, 18),
#   4922710831011201,
#   'fraud_Herzog Ltd',
#   'misc_pos',
#   Decimal('4.27'),
#   'Heather',
#   'Chase',
#   'F',
#   '6888 Hicks Stream Suite 954',
#   'Manor',
#   'PA',
#   15665,
#   Decimal('40.335900000000000'),
#   Decimal('-79.660700000000000'),
#   1472,
#   'Public affairs consultant',
#   datetime.date(1941, 3, 7),
#   'fc28024ce480f8ef21a32d64c93a29f5',
#   1325376318,
#   Decimal('40.351813000000000'),
#   Decimal('-79.958146000000000'),
#   0),
#  (9,
#   datetime.datetime(2019, 1, 1, 0, 6, 1),
#   2720830304681674,
#   'fraud_Schoen, Kuphal and Nitzsche',
#   'grocery_pos',
#   Decimal('198.39'),
#   'Melissa',
#   'Aguilar',
#   'F',
#   '21326 Taylor Squares Suite 708',
#   'Clarksville',
#   'TN',
#   37040,
#   Decimal('36.522000000000000'),
#   Decimal('-87.348999999999990'),
#   151785,
#   'Pathologist',
#   datetime.date(1974, 3, 28),
#   '3b9014ea8fb80bd65de0b1463b00b00e',
#   1325376361,
#   Decimal('37.179198000000000'),
#   Decimal('-87.485381000000000'),
#   0),
#  (10,
#   datetime.datetime(2019, 1, 1, 0, 6, 23),
#   4642894980163,
#   'fraud_Rutherford-Mertz',
#   'grocery_pos',
#   Decimal('24.74'),
#   'Eddie',
#   'Mendez',
#   'M',
#   '1831 Faith View Suite 653',
#   'Clarinda',
#   'IA',
#   51632,
#   Decimal('40.749100000000000'),
#   Decimal('-95.038000000000000'),
#   7297,
#   'IT trainer',
#   datetime.date(1990, 7, 13),
#   'd71c95ab6b7356dd74389d41df429c87',
#   1325376383,
#   Decimal('40.275891000000000'),
#   Decimal('-96.011548000000000'),
#   0),
#  (11,
#   datetime.datetime(2019, 1, 1, 0, 6, 53),
#   377234009633447,
#   'fraud_Kerluke-Abshire',
#   'shopping_net',
#   Decimal('7.77'),
#   'Theresa',
#   'Blackwell',
#   'F',
#   '43576 Kristina Islands',
#   'Shenandoah Junction',
#   'WV',
#   25442,
#   Decimal('39.371600000000000'),
#   Decimal('-77.822900000000000'),
#   1925,
#   'Systems developer',
#   datetime.date(1966, 2, 14),
#   '3c74776e558f1499a7824b556e474b1d',
#   1325376413,
#   Decimal('40.103866000000000'),
#   Decimal('-78.624459000000000'),
#   0),
#  (12,
#   datetime.datetime(2019, 1, 1, 0, 6, 56),
#   180042946491150,
#   'fraud_Lockman Ltd',
#   'grocery_pos',
#   Decimal('71.22'),
#   'Charles',
#   'Robles',
#   'M',
#   '3337 Lisa Divide',
#   'Saint Petersburg',
#   'FL',
#   33710,
#   Decimal('27.789800000000000'),
#   Decimal('-82.724300000000000'),
#   341043,
#   'Engineer, land',
#   datetime.date(1989, 2, 28),
#   'c1d9a7ddb1e34639fe82758de97f4abf',
#   1325376416,
#   Decimal('27.630593000000000'),
#   Decimal('-82.308891000000000'),
#   0),
#  (13,
#   datetime.datetime(2019, 1, 1, 0, 7, 27),
#   5559857416065248,
#   'fraud_Kiehn Inc',
#   'grocery_pos',
#   Decimal('96.29'),
#   'Jack',
#   'Hill',
#   'M',
#   '5916 Susan Bridge Apt. 939',
#   'Grenada',
#   'CA',
#   96038,
#   Decimal('41.612500000000000'),
#   Decimal('-122.525800000000000'),
#   589,
#   'Systems analyst',
#   datetime.date(1945, 12, 21),
#   '413636e759663f264aae1819a4d4f231',
#   1325376447,
#   Decimal('41.657520000000000'),
#   Decimal('-122.230347000000000'),
#   0),
#  (14,
#   datetime.datetime(2019, 1, 1, 0, 9, 3),
#   3514865930894695,
#   'fraud_Beier-Hyatt',
#   'shopping_pos',
#   Decimal('7.77'),
#   'Christopher',
#   'Castaneda',
#   'M',
#   '1632 Cohen Drive Suite 639',
#   'High Rolls Mountain Park',
#   'NM',
#   88325,
#   Decimal('32.939600000000000'),
#   Decimal('-105.818900000000000'),
#   899,
#   'Naval architect',
#   datetime.date(1967, 8, 30),
#   '8a6293af5ed278dea14448ded2685fea',
#   1325376543,
#   Decimal('32.863258000000000'),
#   Decimal('-106.520205000000000'),
#   0),
#  (15,
#   datetime.datetime(2019, 1, 1, 0, 9, 20),
#   6011999606625827,
#   'fraud_Schmidt and Sons',
#   'shopping_net',
#   Decimal('3.26'),
#   'Ronald',
#   'Carson',
#   'M',
#   '870 Rocha Drive',
#   'Harrington Park',
#   'NJ',
#   7640,
#   Decimal('40.991800000000000'),
#   Decimal('-73.980000000000000'),
#   4664,
#   'Radiographer, diagnostic',
#   datetime.date(1965, 6, 30),
#   'baae0b096835c975857eea7e28dde3dc',
#   1325376560,
#   Decimal('41.831174000000000'),
#   Decimal('-74.335559000000000'),
#   0),
#  (16,
#   datetime.datetime(2019, 1, 1, 0, 10, 49),
#   6011860238257910,
#   'fraud_Lebsack and Sons',
#   'misc_net',
#   Decimal('327.00'),
#   'Lisa',
#   'Mendez',
#   'F',
#   '44259 Beth Station Suite 215',
#   'Lahoma',
#   'OK',
#   73754,
#   Decimal('36.385000000000000'),
#   Decimal('-98.072700000000000'),
#   1078,
#   'Programme researcher, broadcasting,film,video',
#   datetime.date(1952, 7, 6),
#   '991c04803b4d4eeab30d6245a872e3d3',
#   1325376649,
#   Decimal('36.384092000000000'),
#   Decimal('-99.048472000000000'),
#   0),
#  (17,
#   datetime.datetime(2019, 1, 1, 0, 10, 58),
#   3565423334076143,
#   'fraud_Mayert Group',
#   'shopping_pos',
#   Decimal('341.67'),
#   'Nathan',
#   'Thomas',
#   'M',
#   '4923 Campbell Pines Suite 717',
#   'Carlisle',
#   'IN',
#   47838,
#   Decimal('38.976300000000000'),
#   Decimal('-87.366700000000000'),
#   4081,
#   'Energy engineer',
#   datetime.date(1938, 3, 15),
#   'f12cf52be2175703db789a4644c32f25',
#   1325376658,
#   Decimal('38.674491000000000'),
#   Decimal('-88.305767000000000'),
#   0),
#  (18,
#   datetime.datetime(2019, 1, 1, 0, 11, 14),
#   2348245054386329,
#   'fraud_Konopelski, Schneider and Hartmann',
#   'food_dining',
#   Decimal('63.07'),
#   'Justin',
#   'Gay',
#   'M',
#   '268 Hayes Rue Suite 811',
#   'Harborcreek',
#   'PA',
#   16421,
#   Decimal('42.176700000000000'),
#   Decimal('-79.941600000000000'),
#   2518,
#   'Event organiser',
#   datetime.date(1946, 2, 2),
#   '8500f3d459047eac8443307b1e8296e5',
#   1325376674,
#   Decimal('41.430274000000000'),
#   Decimal('-79.492553000000000'),
#   0),
#  (19,
#   datetime.datetime(2019, 1, 1, 0, 12, 34),
#   4956828990005111019,
#   'fraud_Schultz, Simonis and Little',
#   'grocery_pos',
#   Decimal('44.71'),
#   'Kenneth',
#   'Robinson',
#   'M',
#   '269 Sanchez Rapids',
#   'Elizabeth',
#   'NJ',
#   7208,
#   Decimal('40.674700000000000'),
#   Decimal('-74.223900000000000'),
#   124967,
#   'Operational researcher',
#   datetime.date(1980, 12, 21),
#   '09eff9c806365e2a6be12c1bbab3d70e',
#   1325376754,
#   Decimal('40.079588000000000'),
#   Decimal('-74.848086999999990'),
#   0),
#  (20,
#   datetime.datetime(2019, 1, 1, 0, 13, 8),
#   4469777115158234880,
#   'fraud_Bauch-Raynor',
#   'grocery_pos',
#   Decimal('57.34'),
#   'Gregory',
#   'Graham',
#   'M',
#   '4005 Dana Glens',
#   'Methuen',
#   'MA',
#   1844,
#   Decimal('42.728000000000000'),
#   Decimal('-71.181000000000000'),
#   47249,
#   'Market researcher',
#   datetime.date(1980, 11, 22),
#   '139a1bee15be607d79fe173bfcb2502a',
#   1325376788,
#   Decimal('42.268760000000000'),
#   Decimal('-71.217297000000000'),
#   0),
#  (21,
#   datetime.datetime(2019, 1, 1, 0, 14, 37),
#   2305336922781618,
#   'fraud_Harris Inc',
#   'gas_transport',
#   Decimal('50.79'),
#   'Jeffrey',
#   'Rice',
#   'M',
#   '21447 Powell Circle',
#   'Moulton',
#   'IA',
#   52572,
#   Decimal('40.686600000000000'),
#   Decimal('-92.683300000000000'),
#   1132,
#   'Probation officer',
#   datetime.date(1961, 2, 14),
#   'b9c4615bec3561c8e83b0c1d6c7028e2',
#   1325376877,
#   Decimal('40.188930000000000'),
#   Decimal('-91.955115000000000'),
#   0),
#  (22,
#   datetime.datetime(2019, 1, 1, 0, 17, 16),
#   180048185037117,
#   'fraud_Kling-Grant',
#   'grocery_net',
#   Decimal('46.28'),
#   'Mary',
#   'Wall',
#   'F',
#   '2481 Mills Lock',
#   'Plainfield',
#   'NJ',
#   7060,
#   Decimal('40.615200000000000'),
#   Decimal('-74.415000000000000'),
#   71485,
#   'Leisure centre manager',
#   datetime.date(1974, 7, 19),
#   '19e23c6a300c774354417befe4f31f8c',
#   1325377036,
#   Decimal('40.021888000000000'),
#   Decimal('-74.228188000000000'),
#   0),
#  (23,
#   datetime.datetime(2019, 1, 1, 0, 17, 40),
#   630441765090,
#   'fraud_Pacocha-Bauch',
#   'shopping_pos',
#   Decimal('9.55'),
#   'Susan',
#   'Washington',
#   'F',
#   '759 Erin Mount Suite 956',
#   'May',
#   'TX',
#   76857,
#   Decimal('31.957100000000000'),
#   Decimal('-98.965600000000000'),
#   1791,
#   'Corporate investment banker',
#   datetime.date(1965, 7, 26),
#   'c4b4daebab8be54cadde4b941244ca53',
#   1325377060,
#   Decimal('31.626350000000000'),
#   Decimal('-98.610225000000000'),
#   0),
#  (24,
#   datetime.datetime(2019, 1, 1, 0, 18, 6),
#   4428780983793657331,
#   'fraud_Lesch Ltd',
#   'shopping_pos',
#   Decimal('22.95'),
#   'Richard',
#   'Waters',
#   'M',
#   '7683 Natasha Way Apt. 945',
#   'Waukesha',
#   'WI',
#   53186,
#   Decimal('42.999300000000000'),
#   Decimal('-88.219600000000000'),
#   95015,
#   'Therapist, occupational',
#   datetime.date(1946, 1, 2),
#   'd2432bfeabf142dc1bae1d426e32aecc',
#   1325377086,
#   Decimal('43.375041000000000'),
#   Decimal('-89.055065000000000'),
#   0),
#  (25,
#   datetime.datetime(2019, 1, 1, 0, 18, 7),
#   343464013864032,
#   'fraud_Kunde-Sanford',
#   'misc_net',
#   Decimal('2.55'),
#   'Jodi',
#   'Foster',
#   'F',
#   '551 Zachary Freeway',
#   'Bailey',
#   'NC',
#   27807,
#   Decimal('35.807200000000000'),
#   Decimal('-78.089200000000000'),
#   6629,
#   'Call centre manager',
#   datetime.date(1962, 8, 13),
#   'abe0676c18f34fa305b113fa762e29b5',
#   1325377087,
#   Decimal('36.749870000000000'),
#   Decimal('-78.677870000000000'),
#   0),
#  (26,
#   datetime.datetime(2019, 1, 1, 0, 20, 15),
#   374930071163758,
#   "fraud_Deckow-O'Conner",
#   'grocery_pos',
#   Decimal('64.09'),
#   'Daniel',
#   'Escobar',
#   'M',
#   '61390 Hayes Port',
#   'Romulus',
#   'MI',
#   48174,
#   Decimal('42.220300000000000'),
#   Decimal('-83.358300000000000'),
#   31515,
#   'Police officer',
#   datetime.date(1971, 11, 5),
#   '6f363661ba6b55889e488dd178f2a0af',
#   1325377215,
#   Decimal('42.360426000000000'),
#   Decimal('-83.552316000000000'),
#   0),
#  (27,
#   datetime.datetime(2019, 1, 1, 0, 21, 32),
#   4334230547694630,
#   'fraud_Bruen-Yost',
#   'misc_pos',
#   Decimal('6.85'),
#   'Scott',
#   'Martin',
#   'M',
#   '7483 Navarro Flats',
#   'Freedom',
#   'WY',
#   83120,
#   Decimal('43.017200000000000'),
#   Decimal('-111.029200000000000'),
#   471,
#   'Education officer, museum',
#   datetime.date(1967, 8, 2),
#   'f3c43d336e92a44fc2fb67058d5949e3',
#   1325377292,
#   Decimal('43.753735000000000'),
#   Decimal('-111.454923000000000'),
#   0),
#  (28,
#   datetime.datetime(2019, 1, 1, 0, 22, 6),
#   4225990116481262579,
#   'fraud_Kunze Inc',
#   'grocery_pos',
#   Decimal('90.22'),
#   'Brian',
#   'Simpson',
#   'M',
#   '2711 Duran Pines',
#   'Honokaa',
#   'HI',
#   96727,
#   Decimal('20.082700000000000'),
#   Decimal('-155.488000000000000'),
#   4878,
#   'Physiotherapist',
#   datetime.date(1966, 12, 3),
#   '95826e3caa9e0b905294c6dae985aec1',
#   1325377326,
#   Decimal('19.560013000000000'),
#   Decimal('-156.045889000000000'),
#   0),
#  (29,
#   datetime.datetime(2019, 1, 1, 0, 22, 18),
#   4260059589824237,
#   'fraud_Nitzsche, Kessler and Wolff',
#   'shopping_pos',
#   Decimal('4.02'),
#   'Aaron',
#   'Rogers',
#   'M',
#   '969 Huerta Path Apt. 270',
#   'Valentine',
#   'NE',
#   69201,
#   Decimal('42.806200000000000'),
#   Decimal('-100.621500000000000'),
#   4005,
#   'Network engineer',
#   datetime.date(1945, 3, 15),
#   '20490f3f0966ce74b4aaba8dc2c4ed52',
#   1325377338,
#   Decimal('42.475590000000000'),
#   Decimal('-101.265846000000000'),
#   0),
#  (30,
#   datetime.datetime(2019, 1, 1, 0, 22, 36),
#   180094608895855,
#   'fraud_Kihn, Abernathy and Douglas',
#   'shopping_net',
#   Decimal('3.66'),
#   'Tammie',
#   'Harper',
#   'F',
#   '57887 Gutierrez Harbor',
#   'Westfir',
#   'OR',
#   97492,
#   Decimal('43.757500000000000'),
#   Decimal('-122.481000000000000'),
#   597,
#   'Forensic psychologist',
#   datetime.date(1961, 5, 19),
#   '870c92b288a974a2faf1f24b05c27e33',
#   1325377356,
#   Decimal('44.278191000000000'),
#   Decimal('-121.815161000000000'),
#   0),
#  (31,
#   datetime.datetime(2019, 1, 1, 0, 22, 39),
#   4599735407877245080,
#   'fraud_Heller, Gutmann and Zieme',
#   'grocery_pos',
#   Decimal('82.80'),
#   'Mary',
#   'Myers',
#   'F',
#   '39787 Pamela Fall Suite 639',
#   'Tiptonville',
#   'TN',
#   38079,
#   Decimal('36.384600000000000'),
#   Decimal('-89.464900000000000'),
#   5577,
#   'Geochemist',
#   datetime.date(1964, 12, 30),
#   'cb598ec00d349dc95e7b3c18de5ae800',
#   1325377359,
#   Decimal('36.294205000000000'),
#   Decimal('-89.811281999999990'),
#   0),
#  (32,
#   datetime.datetime(2019, 1, 1, 0, 22, 44),
#   630412733309,
#   'fraud_Torphy-Goyette',
#   'shopping_pos',
#   Decimal('66.21'),
#   'Heather',
#   'Stanton',
#   'F',
#   '445 Jerry Lights Apt. 081',
#   'Republic',
#   'MI',
#   49879,
#   Decimal('46.368000000000000'),
#   Decimal('-87.993800000000000'),
#   1038,
#   'Armed forces training and education officer',
#   datetime.date(1964, 4, 22),
#   '20f048d3907dbb9978e23bee7b7578ce',
#   1325377364,
#   Decimal('46.412038000000000'),
#   Decimal('-88.516663000000000'),
#   0),
#  (33,
#   datetime.datetime(2019, 1, 1, 0, 23, 41),
#   2712209726293386,
#   'fraud_Balistreri-Nader',
#   'misc_pos',
#   Decimal('25.58'),
#   'Jenna',
#   'Brooks',
#   'F',
#   '50872 Alex Plain Suite 088',
#   'Baton Rouge',
#   'LA',
#   70808,
#   Decimal('30.406600000000000'),
#   Decimal('-91.146800000000000'),
#   378909,
#   'Designer, furniture',
#   datetime.date(1977, 2, 22),
#   '1654da2abfb9e79a5f99167fc9779558',
#   1325377421,
#   Decimal('29.737426000000000'),
#   Decimal('-90.853194000000000'),
#   0),
#  (34,
#   datetime.datetime(2019, 1, 1, 0, 23, 58),
#   374125201044065,
#   'fraud_Bahringer, Schoen and Corkery',
#   'shopping_pos',
#   Decimal('9.03'),
#   'Christopher',
#   'Gilbert',
#   'M',
#   '20937 Reed Lakes Apt. 271',
#   'Washington',
#   'DC',
#   20012,
#   Decimal('38.975700000000000'),
#   Decimal('-77.028200000000000'),
#   601723,
#   'Optician, dispensing',
#   datetime.date(1970, 7, 20),
#   'c733711c521c41c578f4a964d8350df0',
#   1325377438,
#   Decimal('38.880898000000000'),
#   Decimal('-76.441116000000010'),
#   0),
#  (35,
#   datetime.datetime(2019, 1, 1, 0, 25, 46),
#   349612764943496,
#   'fraud_Hudson-Ratke',
#   'grocery_pos',
#   Decimal('99.00'),
#   'Xavier',
#   'Beltran',
#   'M',
#   '61107 Edwards Dam Apt. 463',
#   'Big Creek',
#   'KY',
#   40914,
#   Decimal('37.104600000000000'),
#   Decimal('-83.570600000000000'),
#   467,
#   'Psychologist, forensic',
#   datetime.date(1984, 6, 4),
#   '7e2f9596cb3a3595ece15611ee338e5c',
#   1325377546,
#   Decimal('36.823545000000000'),
#   Decimal('-83.901040000000010'),
#   0),
#  (36,
#   datetime.datetime(2019, 1, 1, 0, 26, 22),
#   3598215285024754,
#   'fraud_Heidenreich PLC',
#   'grocery_pos',
#   Decimal('207.36'),
#   'Ashley',
#   'Lopez',
#   'F',
#   '9333 Valentine Point',
#   'Bellmore',
#   'NY',
#   11710,
#   Decimal('40.672900000000000'),
#   Decimal('-73.536500000000000'),
#   34496,
#   'Librarian, public',
#   datetime.date(1970, 10, 21),
#   'f246ac27c09429ff1e385d4683c79c4d',
#   1325377582,
#   Decimal('40.202538000000000'),
#   Decimal('-73.859212000000000'),
#   0),
#  (37,
#   datetime.datetime(2019, 1, 1, 0, 27, 45),
#   213141712584544,
#   'fraud_Halvorson Group',
#   'misc_pos',
#   Decimal('181.35'),
#   'Margaret',
#   'Curtis',
#   'F',
#   '742 Oneill Shore',
#   'Florence',
#   'MS',
#   39073,
#   Decimal('32.153000000000000'),
#   Decimal('-90.121700000000000'),
#   19685,
#   'Fine artist',
#   datetime.date(1984, 12, 24),
#   '7bb25a43205191eb7344282b88fc54d3',
#   1325377665,
#   Decimal('31.939812000000000'),
#   Decimal('-90.726209000000000'),
#   0),
#  (38,
#   datetime.datetime(2019, 1, 1, 0, 27, 56),
#   30561214688470,
#   'fraud_Harber Inc',
#   'gas_transport',
#   Decimal('82.22'),
#   'Gina',
#   'Morrison',
#   'F',
#   '41851 Victor Drives Suite 219',
#   'Allentown',
#   'PA',
#   18103,
#   Decimal('40.589100000000000'),
#   Decimal('-75.464500000000000'),
#   166081,
#   'Scientist, research (maths)',
#   datetime.date(1998, 10, 1),
#   '61bcb858dd5c8e2d0d46d02b4fa0bf8e',
#   1325377676,
#   Decimal('40.586238000000000'),
#   Decimal('-75.802249000000000'),
#   0),
#  (39,
#   datetime.datetime(2019, 1, 1, 0, 29, 11),
#   4789911625179723,
#   'fraud_Mosciski, Gislason and Mertz',
#   'grocery_pos',
#   Decimal('221.81'),
#   'Dorothy',
#   'Zuniga',
#   'F',
#   '77321 Ford Via',
#   'Moriches',
#   'NY',
#   11955,
#   Decimal('40.809500000000000'),
#   Decimal('-72.822900000000000'),
#   3285,
#   'Research officer, trade union',
#   datetime.date(1988, 4, 27),
#   'a8394c3e555166ce2f90eee628bd9ade',
#   1325377751,
#   Decimal('40.011959000000000'),
#   Decimal('-72.594808000000000'),
#   0),
#  (40,
#   datetime.datetime(2019, 1, 1, 0, 30, 49),
#   676372984911,
#   'fraud_Christiansen, Goyette and Schamberger',
#   'gas_transport',
#   Decimal('53.60'),
#   'Vicki',
#   'Mendoza',
#   'F',
#   '3645 Atkins Island Apt. 238',
#   'Esbon',
#   'KS',
#   66941,
#   Decimal('39.756200000000000'),
#   Decimal('-98.446200000000000'),
#   242,
#   'Tourism officer',
#   datetime.date(1987, 7, 18),
#   'f1566e9623814dd277dfa2a9bf83ea36',
#   1325377849,
#   Decimal('40.332519000000000'),
#   Decimal('-99.062962000000000'),
#   0),
#  (41,
#   datetime.datetime(2019, 1, 1, 0, 31, 1),
#   30011465039817,
#   'fraud_Howe Ltd',
#   'misc_pos',
#   Decimal('54.02'),
#   'Lisa',
#   'Garcia',
#   'F',
#   '213 Gill Expressway',
#   'Chatham',
#   'NY',
#   12037,
#   Decimal('42.349600000000000'),
#   Decimal('-73.587300000000000'),
#   4015,
#   'Human resources officer',
#   datetime.date(1971, 10, 14),
#   '8d11abad6bc3501f9994f061e3a5b730',
#   1325377861,
#   Decimal('42.041783000000000'),
#   Decimal('-73.076424000000000'),
#   0),
#  (42,
#   datetime.datetime(2019, 1, 1, 0, 31, 51),
#   4642255475285942,
#   'fraud_Ledner-Pfannerstill',
#   'gas_transport',
#   Decimal('102.13'),
#   'Sabrina',
#   'Johnson',
#   'F',
#   '320 Nicholson Orchard',
#   'Thompson',
#   'UT',
#   84540,
#   Decimal('38.999900000000000'),
#   Decimal('-109.615000000000000'),
#   46,
#   'Surveyor, minerals',
#   datetime.date(1987, 4, 23),
#   '47238da5b40d126c8abea40a857c7809',
#   1325377911,
#   Decimal('39.807313000000000'),
#   Decimal('-109.348294000000000'),
#   0),
#  (43,
#   datetime.datetime(2019, 1, 1, 0, 32, 15),
#   30074693890476,
#   'fraud_Lockman Ltd',
#   'grocery_pos',
#   Decimal('212.75'),
#   'Kelsey',
#   'Richards',
#   'F',
#   '889 Sarah Station Suite 624',
#   'Holcomb',
#   'KS',
#   67851,
#   Decimal('37.993100000000000'),
#   Decimal('-100.989300000000000'),
#   2691,
#   'Arboriculturist',
#   datetime.date(1993, 8, 16),
#   'd9dcde500bed2cad48ee41e44c362596',
#   1325377935,
#   Decimal('38.862183000000000'),
#   Decimal('-101.234087000000000'),
#   0),
#  (44,
#   datetime.datetime(2019, 1, 1, 0, 32, 15),
#   180067784565096,
#   'fraud_Koepp-Witting',
#   'grocery_pos',
#   Decimal('130.40'),
#   'Mary',
#   'Juarez',
#   'F',
#   '35440 Ryan Islands',
#   'North Prairie',
#   'WI',
#   53153,
#   Decimal('42.938500000000000'),
#   Decimal('-88.395000000000000'),
#   2328,
#   'Applications developer',
#   datetime.date(1942, 1, 6),
#   '14a6e29ac65424550ea7e7c9f551dbb8',
#   1325377935,
#   Decimal('42.236269000000000'),
#   Decimal('-88.397336000000000'),
#   0),
#  (45,
#   datetime.datetime(2019, 1, 1, 0, 32, 47),
#   213126662687660,
#   'fraud_Doyle Ltd',
#   'grocery_pos',
#   Decimal('91.16'),
#   'Christopher',
#   'Luna',
#   'M',
#   '242 Brian Mountain',
#   'Laredo',
#   'TX',
#   78040,
#   Decimal('27.515500000000000'),
#   Decimal('-99.498600000000000'),
#   248858,
#   'Video editor',
#   datetime.date(1971, 1, 28),
#   '685bcca9eb5ce554134d7242d564ecc9',
#   1325377967,
#   Decimal('27.588953000000004'),
#   Decimal('-99.816911000000000'),
#   0),
#  (46,
#   datetime.datetime(2019, 1, 1, 0, 33, 51),
#   2266735643685262,
#   'fraud_Schaefer, Maggio and Daugherty',
#   'gas_transport',
#   Decimal('55.78'),
#   'Carlos',
#   'Chung',
#   'M',
#   '8957 Russell Key',
#   'Grant',
#   'AL',
#   35747,
#   Decimal('34.495900000000000'),
#   Decimal('-86.259000000000000'),
#   5901,
#   'Curator',
#   datetime.date(1972, 7, 25),
#   '392529cae1f1f1647093732a8f319c50',
#   1325378031,
#   Decimal('35.255978000000006'),
#   Decimal('-86.041872000000000'),
#   0),
#  (47,
#   datetime.datetime(2019, 1, 1, 0, 34, 10),
#   3553629419254918,
#   'fraud_Stracke-Lemke',
#   'grocery_pos',
#   Decimal('83.07'),
#   'Sharon',
#   'Johnson',
#   'F',
#   '7202 Jeffrey Mills',
#   'Conway',
#   'WA',
#   98238,
#   Decimal('48.340000000000000'),
#   Decimal('-122.345600000000000'),
#   85,
#   'Research officer, political party',
#   datetime.date(1984, 9, 1),
#   '9b7a0619dcc5c572dc134f2827ed5a6b',
#   1325378050,
#   Decimal('48.682111000000000'),
#   Decimal('-122.719904000000000'),
#   0),
#  (48,
#   datetime.datetime(2019, 1, 1, 0, 36, 12),
#   3511058278399773,
#   'fraud_Mosciski, Ziemann and Farrell',
#   'shopping_net',
#   Decimal('4.38'),
#   'Briana',
#   'Santos',
#   'F',
#   '702 Tabitha Drive',
#   'New Goshen',
#   'IN',
#   47863,
#   Decimal('39.580300000000000'),
#   Decimal('-87.461600000000000'),
#   205,
#   'Engineer, mining',
#   datetime.date(1960, 1, 6),
#   'f1e1ad954f49955c37b45eb71b2d1642',
#   1325378172,
#   Decimal('39.681736000000000'),
#   Decimal('-88.323862000000000'),
#   0),
#  (49,
#   datetime.datetime(2019, 1, 1, 0, 36, 58),
#   4110266553600176127,
#   'fraud_Cartwright-Harris',
#   'grocery_pos',
#   Decimal('130.89'),
#   'Sandra',
#   'Schwartz',
#   'F',
#   '3789 Mark Walks',
#   'Sunflower',
#   'MS',
#   38778,
#   Decimal('33.556700000000000'),
#   Decimal('-90.545100000000000'),
#   1686,
#   'Education officer, community',
#   datetime.date(1986, 11, 6),
#   'e02fd7d82af517718f83a3f05077d435',
#   1325378218,
#   Decimal('33.595647000000000'),
#   Decimal('-90.234118000000000'),
#   0),
#  (50,
#   datetime.datetime(2019, 1, 1, 0, 37, 18),
#   4265776278887457,
#   "fraud_Pacocha-O'Reilly",
#   'grocery_pos',
#   Decimal('103.00'),
#   'Christine',
#   'Best',
#   'F',
#   '68248 Deanna Land',
#   'Enola',
#   'AR',
#   72047,
#   Decimal('35.208700000000000'),
#   Decimal('-92.212300000000000'),
#   969,
#   'Physicist, medical',
#   datetime.date(1954, 1, 5),
#   '289789e617eece42a9cafe36680b1b69',
#   1325378238,
#   Decimal('35.034285000000000'),
#   Decimal('-92.343010000000000'),
#   0),
#  (51,
#   datetime.datetime(2019, 1, 1, 0, 39, 22),
#   3583793405872580,
#   'fraud_Pfeffer LLC',
#   'grocery_net',
#   Decimal('50.82'),
#   'Beth',
#   'Lambert',
#   'F',
#   '6447 Johnson Estates Apt. 986',
#   'Roosevelt',
#   'OK',
#   73564,
#   Decimal('34.847000000000000'),
#   Decimal('-98.983600000000000'),
#   551,
#   'Amenity horticulturist',
#   datetime.date(1970, 9, 27),
#   '64a6d4be2510d764cbd869cd2a57a4fd',
#   1325378362,
#   Decimal('34.852665000000000'),
#   Decimal('-98.902670000000000'),
#   0),
#  (52,
#   datetime.datetime(2019, 1, 1, 0, 39, 37),
#   213193596103206,
#   'fraud_Huels-Hahn',
#   'gas_transport',
#   Decimal('60.77'),
#   'James',
#   'Hunt',
#   'M',
#   '7369 Gabriel Tunnel',
#   'Pointe Aux Pins',
#   'MI',
#   49775,
#   Decimal('45.754900000000000'),
#   Decimal('-84.447000000000000'),
#   95,
#   'Electrical engineer',
#   datetime.date(1994, 2, 9),
#   '211c26efcb0ed5e87d4700daee23e070',
#   1325378377,
#   Decimal('45.323099000000000'),
#   Decimal('-85.116543000000010'),
#   0),
#  (53,
#   datetime.datetime(2019, 1, 1, 0, 39, 43),
#   60495593109,
#   'fraud_Volkman PLC',
#   'food_dining',
#   Decimal('122.86'),
#   'Randall',
#   'Dillon',
#   'M',
#   '4440 George Mills Suite 591',
#   'Dallas',
#   'TX',
#   75210,
#   Decimal('32.769900000000000'),
#   Decimal('-96.743000000000000'),
#   1263321,
#   'Television camera operator',
#   datetime.date(1942, 11, 24),
#   '7d68e49b63d845b808108fcd41c15877',
#   1325378383,
#   Decimal('32.282224000000000'),
#   Decimal('-97.461830000000000'),
#   0),
#  (54,
#   datetime.datetime(2019, 1, 1, 0, 40, 44),
#   4725837176265195730,
#   'fraud_Kiehn-Emmerich',
#   'grocery_pos',
#   Decimal('212.45'),
#   'Elizabeth',
#   'Mckee',
#   'F',
#   '358 Pruitt Square',
#   'Jay',
#   'FL',
#   32565,
#   Decimal('30.898500000000000'),
#   Decimal('-87.133200000000000'),
#   5719,
#   'Higher education careers adviser',
#   datetime.date(1994, 11, 5),
#   '88fde595524ba43924f36bd397b86413',
#   1325378444,
#   Decimal('31.414174000000000'),
#   Decimal('-87.138632000000000'),
#   0),
#  (55,
#   datetime.datetime(2019, 1, 1, 0, 40, 48),
#   30404291151692,
#   'fraud_Kemmer-Buckridge',
#   'misc_pos',
#   Decimal('7.33'),
#   'Savannah',
#   'Lewis',
#   'F',
#   '537 Walker Freeway',
#   'North Tonawanda',
#   'NY',
#   14120,
#   Decimal('43.049800000000000'),
#   Decimal('-78.851000000000000'),
#   45100,
#   'Ambulance person',
#   datetime.date(1993, 10, 25),
#   '01620e8ae84989a6f95581855e49da99',
#   1325378448,
#   Decimal('43.176300000000000'),
#   Decimal('-77.901777000000000'),
#   0),
#  (56,
#   datetime.datetime(2019, 1, 1, 0, 40, 50),
#   213178850083780,
#   'fraud_Cummerata-Jones',
#   'gas_transport',
#   Decimal('70.53'),
#   'Shawn',
#   'King',
#   'M',
#   '31493 Garcia Summit',
#   'Athena',
#   'OR',
#   97813,
#   Decimal('45.828900000000000'),
#   Decimal('-118.497100000000000'),
#   1302,
#   'Dealer',
#   datetime.date(1976, 10, 18),
#   '7b91bd200c11c5cd24b43694e12b5bbc',
#   1325378450,
#   Decimal('46.043252000000000'),
#   Decimal('-117.962133000000000'),
#   0),
#  (57,
#   datetime.datetime(2019, 1, 1, 0, 40, 58),
#   2356276337669917,
#   'fraud_Goldner, Kovacek and Abbott',
#   'grocery_pos',
#   Decimal('58.26'),
#   'Benjamin',
#   'Harris',
#   'M',
#   '0881 Lori Pines',
#   'Chester',
#   'MD',
#   21619,
#   Decimal('38.958300000000000'),
#   Decimal('-76.284200000000000'),
#   5848,
#   'Paediatric nurse',
#   datetime.date(1981, 2, 15),
#   'd94f89d7360cd6bade6cf1b73d003e8f',
#   1325378458,
#   Decimal('39.240962000000000'),
#   Decimal('-76.712731999999990'),
#   0),
#  (58,
#   datetime.datetime(2019, 1, 1, 0, 41, 43),
#   3568736585751727,
#   'fraud_Spinka-Welch',
#   'grocery_net',
#   Decimal('50.45'),
#   'Thomas',
#   'Cross',
#   'M',
#   '7566 Thompson Creek Apt. 827',
#   'Elkhart',
#   'IA',
#   50073,
#   Decimal('41.811400000000000'),
#   Decimal('-93.485500000000000'),
#   1195,
#   'Trading standards officer',
#   datetime.date(1974, 3, 13),
#   '16e0d3920a0e896a70fa54e7162165c0',
#   1325378503,
#   Decimal('41.776673000000000'),
#   Decimal('-93.350689000000000'),
#   0),
#  (59,
#   datetime.datetime(2019, 1, 1, 0, 41, 45),
#   4642255475285942,
#   'fraud_Huel-Langworth',
#   'misc_net',
#   Decimal('177.57'),
#   'Sabrina',
#   'Johnson',
#   'F',
#   '320 Nicholson Orchard',
#   'Thompson',
#   'UT',
#   84540,
#   Decimal('38.999900000000000'),
#   Decimal('-109.615000000000000'),
#   46,
#   'Surveyor, minerals',
#   datetime.date(1987, 4, 23),
#   '048dc7fc7ae8efd51f59f7176e6a8bd7',
#   1325378505,
#   Decimal('38.419431000000000'),
#   Decimal('-109.380252000000000'),
#   0),
#  (60,
#   datetime.datetime(2019, 1, 1, 0, 42, 26),
#   4509142395811241,
#   'fraud_Macejkovic-Lesch',
#   'shopping_pos',
#   Decimal('8.57'),
#   'Margaret',
#   'Williams',
#   'F',
#   '165 Jerry Meadows Suite 460',
#   'Surrency',
#   'GA',
#   31563,
#   Decimal('31.648900000000000'),
#   Decimal('-82.198200000000000'),
#   1324,
#   'Engineer, technical sales',
#   datetime.date(1926, 7, 12),
#   '70ed1a189a6bce479e564b120f2379d9',
#   1325378546,
#   Decimal('32.023302000000000'),
#   Decimal('-82.583450000000000'),
#   0),
#  (61,
#   datetime.datetime(2019, 1, 1, 0, 43, 38),
#   3547560454237873,
#   'fraud_Corwin-Collins',
#   'gas_transport',
#   Decimal('56.66'),
#   'Jerry',
#   'Robinson',
#   'M',
#   '212 Mary Stream',
#   'Arcadia',
#   'MI',
#   49613,
#   Decimal('44.523200000000000'),
#   Decimal('-86.206100000000000'),
#   680,
#   'Designer, jewellery',
#   datetime.date(1966, 12, 21),
#   '144d8b04f90eb30e8df105a091212d99',
#   1325378618,
#   Decimal('44.005290000000000'),
#   Decimal('-86.251990000000000'),
#   0),
#  (62,
#   datetime.datetime(2019, 1, 1, 0, 44, 20),
#   4433091568498503,
#   'fraud_Morar Inc',
#   'grocery_net',
#   Decimal('75.34'),
#   'Linda',
#   'Davis',
#   'F',
#   '493 Todd Views',
#   'Gaithersburg',
#   'MD',
#   20882,
#   Decimal('39.233500000000000'),
#   Decimal('-77.145800000000000'),
#   135332,
#   'Clinical biochemist',
#   datetime.date(1936, 3, 28),
#   'd6b7e57ba04fbb046f93a87301e493cb',
#   1325378660,
#   Decimal('38.817293000000000'),
#   Decimal('-77.833468000000010'),
#   0),
#  (63,
#   datetime.datetime(2019, 1, 1, 0, 44, 43),
#   2720433095629877,
#   'fraud_Eichmann, Bogan and Rodriguez',
#   'gas_transport',
#   Decimal('62.54'),
#   'Mark',
#   'Wood',
#   'M',
#   '854 Walker Dale Suite 488',
#   'Bowdoin',
#   'ME',
#   4287,
#   Decimal('44.057500000000000'),
#   Decimal('-69.965600000000000'),
#   3224,
#   'Engineer, electronics',
#   datetime.date(1997, 8, 22),
#   '2eb55ba0572d67a64baaa8c463878d8c',
#   1325378683,
#   Decimal('43.585423000000000'),
#   Decimal('-70.449359000000000'),
#   0),
#  (64,
#   datetime.datetime(2019, 1, 1, 0, 45, 13),
#   4716561796955522,
#   'fraud_Huel, Hammes and Witting',
#   'grocery_pos',
#   Decimal('92.84'),
#   'Lauren',
#   'Anderson',
#   'F',
#   '11014 Chad Lake Apt. 573',
#   'Heart Butte',
#   'MT',
#   59448,
#   Decimal('48.277700000000000'),
#   Decimal('-112.845600000000000'),
#   743,
#   'Water engineer',
#   datetime.date(1972, 5, 4),
#   '985ebf94aa7a3beeb927d07f77f0354c',
#   1325378713,
#   Decimal('49.080153000000000'),
#   Decimal('-113.532380000000000'),
#   0),
#  (65,
#   datetime.datetime(2019, 1, 1, 0, 46, 18),
#   3536918668124647,
#   'fraud_Ferry, Lynch and Kautzer',
#   'misc_net',
#   Decimal('2.76'),
#   'Michelle',
#   'Juarez',
#   'F',
#   '44864 Melton Vista Suite 310',
#   'San Jose',
#   'CA',
#   95148,
#   Decimal('37.330400000000000'),
#   Decimal('-121.791300000000000'),
#   973849,
#   'Science writer',
#   datetime.date(1955, 6, 12),
#   '70ca7fe41f09770d724a027152dcb9f0',
#   1325378778,
#   Decimal('37.548452000000005'),
#   Decimal('-121.536454000000000'),
#   0),
#  (66,
#   datetime.datetime(2019, 1, 1, 0, 47, 55),
#   3525668150756629,
#   'fraud_Heathcote LLC',
#   'shopping_net',
#   Decimal('101.35'),
#   'Christopher',
#   'Choi',
#   'M',
#   '04611 Sandra Spring Suite 059',
#   'Rumely',
#   'MI',
#   49826,
#   Decimal('46.348100000000000'),
#   Decimal('-87.043600000000000'),
#   137,
#   'Film,video editor',
#   datetime.date(1990, 8, 13),
#   'dab9571cce549056d3c6fedc525ccf23',
#   1325378875,
#   Decimal('46.796891000000000'),
#   Decimal('-86.331091000000000'),
#   0),
#  (67,
#   datetime.datetime(2019, 1, 1, 0, 48, 9),
#   4707867759656333,
#   'fraud_Huel-Langworth',
#   'misc_net',
#   Decimal('303.47'),
#   'Susan',
#   'Shah',
#   'F',
#   '9016 Jordan Bypass Apt. 516',
#   'Cranks',
#   'KY',
#   40820,
#   Decimal('36.755800000000000'),
#   Decimal('-83.183800000000000'),
#   581,
#   'Psychologist, counselling',
#   datetime.date(1967, 2, 4),
#   'cdb332a151bdd568d98837b9e19043b8',
#   1325378889,
#   Decimal('36.394203000000005'),
#   Decimal('-82.514282999999990'),
#   0),
#  (68,
#   datetime.datetime(2019, 1, 1, 0, 49, 25),
#   4666314527820883145,
#   'fraud_Little, Gutmann and Lynch',
#   'shopping_net',
#   Decimal('83.52'),
#   'Guy',
#   'Thompson',
#   'M',
#   '5812 Ramos Oval Suite 598',
#   'Ravenna',
#   'NE',
#   68869,
#   Decimal('41.023300000000000'),
#   Decimal('-98.904100000000000'),
#   2202,
#   'Solicitor, Scotland',
#   datetime.date(1974, 6, 21),
#   '5f7aafc802c8acb5924041bca310040f',
#   1325378965,
#   Decimal('40.992141000000000'),
#   Decimal('-98.831582000000000'),
#   0),
#  (69,
#   datetime.datetime(2019, 1, 1, 0, 49, 31),
#   2248735346244816,
#   'fraud_Torphy-Goyette',
#   'shopping_pos',
#   Decimal('9.97'),
#   'Jacob',
#   'Weber',
#   'M',
#   '29156 Mark Park Apt. 108',
#   'Utica',
#   'KS',
#   67584,
#   Decimal('38.641100000000000'),
#   Decimal('-100.138000000000000'),
#   269,
#   'Product,process development scientist',
#   datetime.date(1962, 11, 11),
#   '22be5ae91a9497c54279abdb4b25210d',
#   1325378971,
#   Decimal('38.075226000000000'),
#   Decimal('-99.138453000000000'),
#   0),
#  (70,
#   datetime.datetime(2019, 1, 1, 0, 50, 53),
#   4512828414983801773,
#   'fraud_Jaskolski-Dibbert',
#   'grocery_net',
#   Decimal('16.16'),
#   'Monica',
#   'Cohen',
#   'F',
#   '864 Reynolds Plains',
#   'Uledi',
#   'PA',
#   15484,
#   Decimal('39.893600000000000'),
#   Decimal('-79.785600000000000'),
#   328,
#   'Tree surgeon',
#   datetime.date(1983, 7, 25),
#   '514a1b5251ca91aeab8994cf6253f04b',
#   1325379053,
#   Decimal('39.222743000000000'),
#   Decimal('-78.839099000000000'),
#   0),
#  (71,
#   datetime.datetime(2019, 1, 1, 0, 52, 57),
#   3501509250702469,
#   'fraud_Hackett-Lueilwitz',
#   'grocery_pos',
#   Decimal('59.56'),
#   'Frank',
#   'Anderson',
#   'M',
#   '0611 Stafford Valley Suite 504',
#   'Naples',
#   'FL',
#   34112,
#   Decimal('26.118400000000000'),
#   Decimal('-81.736100000000000'),
#   276002,
#   'Programme researcher, broadcasting,film,video',
#   datetime.date(1979, 1, 2),
#   'e922037de4ac8a6bec29be758e4ce195',
#   1325379177,
#   Decimal('25.801181000000000'),
#   Decimal('-82.351291000000000'),
#   0),
#  (72,
#   datetime.datetime(2019, 1, 1, 0, 55, 5),
#   30273037698427,
#   'fraud_Cummings LLC',
#   'gas_transport',
#   Decimal('57.23'),
#   'Andrew',
#   'Patterson',
#   'M',
#   '06959 Stephen Branch Suite 246',
#   'Thida',
#   'AR',
#   72165,
#   Decimal('35.576200000000000'),
#   Decimal('-91.453900000000000'),
#   111,
#   'Careers information officer',
#   datetime.date(2000, 6, 13),
#   '044fca5318d0550ed661b507b216f83c',
#   1325379305,
#   Decimal('36.144895000000000'),
#   Decimal('-92.188172000000000'),
#   0),
#  (73,
#   datetime.datetime(2019, 1, 1, 0, 56, 12),
#   3558881852140592,
#   'fraud_Swaniawski, Lowe and Robel',
#   'shopping_pos',
#   Decimal('317.14'),
#   'Christopher',
#   'Holt',
#   'M',
#   '05597 Michael Spurs',
#   'Parks',
#   'AZ',
#   86018,
#   Decimal('35.256300000000000'),
#   Decimal('-111.950000000000000'),
#   759,
#   'Geologist, engineering',
#   datetime.date(1957, 3, 28),
#   '3fe3286b0ea3f8c8857ec2e3da17b853',
#   1325379372,
#   Decimal('35.268124000000000'),
#   Decimal('-112.682895000000000'),
#   0),
#  (74,
#   datetime.datetime(2019, 1, 1, 0, 56, 44),
#   30487648872433,
#   'fraud_Osinski, Ledner and Leuschke',
#   'grocery_pos',
#   Decimal('127.88'),
#   'Stephanie',
#   'Crane',
#   'F',
#   '144 Martinez Curve',
#   'Central',
#   'IN',
#   47110,
#   Decimal('38.097000000000000'),
#   Decimal('-86.172300000000000'),
#   350,
#   'Counsellor',
#   datetime.date(1955, 1, 5),
#   '02384110799958e20345759c49a8910b',
#   1325379404,
#   Decimal('38.860981000000000'),
#   Decimal('-86.773395999999990'),
#   0),
#  (75,
#   datetime.datetime(2019, 1, 1, 0, 56, 59),
#   571465035400,
#   'fraud_Reichert, Huels and Hoppe',
#   'shopping_net',
#   Decimal('113.40'),
#   'Louis',
#   'Fisher',
#   'M',
#   '45654 Hess Rest',
#   'Fort Washakie',
#   'WY',
#   82514,
#   Decimal('43.004800000000000'),
#   Decimal('-108.896400000000000'),
#   1645,
#   'Freight forwarder',
#   datetime.date(1976, 2, 26),
#   '9d660a18154a3ba5fe869f373c6f819c',
#   1325379419,
#   Decimal('42.868965000000000'),
#   Decimal('-108.503350000000000'),
#   0),
#  (76,
#   datetime.datetime(2019, 1, 1, 0, 57, 17),
#   378006354724784,
#   'fraud_Ankunding LLC',
#   'shopping_net',
#   Decimal('94.53'),
#   'Christopher',
#   'Matthews',
#   'M',
#   '433 John Heights Apt. 849',
#   'Etlan',
#   'VA',
#   22719,
#   Decimal('38.509500000000000'),
#   Decimal('-78.263800000000000'),
#   395,
#   'Senior tax professional,tax inspector',
#   datetime.date(1982, 1, 7),
#   'd513918bedeff433054b9384483bd79c',
#   1325379437,
#   Decimal('37.846760000000000'),
#   Decimal('-79.262334000000000'),
#   0),
#  (77,
#   datetime.datetime(2019, 1, 1, 0, 57, 30),
#   341283058448499,
#   'fraud_Pfeffer and Sons',
#   'shopping_pos',
#   Decimal('1.82'),
#   'Mario',
#   'Johns',
#   'M',
#   '62130 Miller Square Suite 785',
#   'Brinson',
#   'GA',
#   39825,
#   Decimal('30.978800000000000'),
#   Decimal('-84.737300000000000'),
#   1461,
#   'Engineer, broadcasting (operations)',
#   datetime.date(1935, 9, 8),
#   '35dd52e536ac27feca9d33ad8426f579',
#   1325379450,
#   Decimal('31.973466000000000'),
#   Decimal('-84.244731000000000'),
#   0),
#  (78,
#   datetime.datetime(2019, 1, 1, 0, 58, 2),
#   4481131401752,
#   'fraud_Greenholt, Jacobi and Gleason',
#   'gas_transport',
#   Decimal('75.77'),
#   'Frank',
#   'Foster',
#   'M',
#   '37910 Ward Lights',
#   'Shrewsbury',
#   'MA',
#   1545,
#   Decimal('42.284800000000000'),
#   Decimal('-71.720500000000000'),
#   35299,
#   'English as a second language teacher',
#   datetime.date(1975, 4, 30),
#   '1240cd77c20744f96aa5e6a5cf9b1fcf',
#   1325379482,
#   Decimal('42.889256000000000'),
#   Decimal('-71.888106999999990'),
#   0),
#  (79,
#   datetime.datetime(2019, 1, 1, 0, 58, 53),
#   4687263141103,
#   'fraud_Kunze Inc',
#   'grocery_pos',
#   Decimal('108.59'),
#   'Sarah',
#   'Cross',
#   'F',
#   '273 Phillip Throughway',
#   'Bigelow',
#   'MN',
#   56117,
#   Decimal('43.533600000000000'),
#   Decimal('-95.651500000000000'),
#   399,
#   'Economist',
#   datetime.date(1977, 4, 28),
#   'c7398ef8cebfefee82e590d473cf538b',
#   1325379533,
#   Decimal('44.511030000000000'),
#   Decimal('-95.934394000000000'),
#   0),
#  (80,
#   datetime.datetime(2019, 1, 1, 0, 59, 25),
#   5456776410929288,
#   'fraud_Harris Inc',
#   'gas_transport',
#   Decimal('48.68'),
#   'Taylor',
#   'Khan',
#   'F',
#   '658 Diane Glen Apt. 677',
#   'North Washington',
#   'PA',
#   16048,
#   Decimal('41.047200000000000'),
#   Decimal('-79.808900000000000'),
#   139,
#   'Patent attorney',
#   datetime.date(1954, 5, 25),
#   '673b35c970ef05a2acceb2af42f919d7',
#   1325379565,
#   Decimal('40.237898000000000'),
#   Decimal('-79.894072999999990'),
#   0),
#  (81,
#   datetime.datetime(2019, 1, 1, 1, 0, 19),
#   4981132848794,
#   'fraud_Connelly, Reichert and Fritsch',
#   'gas_transport',
#   Decimal('72.35'),
#   'Joseph',
#   'Spencer',
#   'M',
#   '7854 Stephanie Island Suite 788',
#   'Holloway',
#   'OH',
#   43985,
#   Decimal('40.011300000000000'),
#   Decimal('-80.970100000000000'),
#   128,
#   'Child psychotherapist',
#   datetime.date(1946, 4, 3),
#   'cfe0948d7b26c9fef58e59a9bf41d3e5',
#   1325379619,
#   Decimal('39.308098000000000'),
#   Decimal('-81.698525000000000'),
#   0),
#  (82,
#   datetime.datetime(2019, 1, 1, 1, 0, 48),
#   6011893664860915,
#   'fraud_Howe Ltd',
#   'misc_pos',
#   Decimal('218.71'),
#   'Erin',
#   'Chavez',
#   'F',
#   '3379 Williams Common',
#   'Littleton',
#   'CO',
#   80120,
#   Decimal('39.599400000000000'),
#   Decimal('-105.004400000000000'),
#   320420,
#   'Water engineer',
#   datetime.date(1975, 7, 31),
#   '43204045928cb3449edc63078a75b48c',
#   1325379648,
#   Decimal('39.335171000000000'),
#   Decimal('-104.102882000000000'),
#   0),
#  (83,
#   datetime.datetime(2019, 1, 1, 1, 1, 48),
#   6534628260579800,
#   'fraud_Torp-Labadie',
#   'gas_transport',
#   Decimal('52.59'),
#   'Christine',
#   'Harris',
#   'F',
#   '29606 Martinez Views Suite 653',
#   'Hinesburg',
#   'VT',
#   5461,
#   Decimal('44.334600000000000'),
#   Decimal('-73.098000000000000'),
#   4542,
#   'Claims inspector,assessor',
#   datetime.date(1998, 3, 19),
#   '2686067ebeee0aa355a750faf309384e',
#   1325379708,
#   Decimal('45.084808000000000'),
#   Decimal('-73.626071000000000'),
#   0),
#  (84,
#   datetime.datetime(2019, 1, 1, 1, 2, 16),
#   376028110684021,
#   'fraud_Wolf Inc',
#   'grocery_pos',
#   Decimal('89.11'),
#   'Aaron',
#   'Murray',
#   'M',
#   '624 Hale Springs Apt. 572',
#   'Meadville',
#   'MO',
#   64659,
#   Decimal('39.779500000000000'),
#   Decimal('-93.301400000000000'),
#   964,
#   'Tourist information centre manager',
#   datetime.date(1974, 12, 23),
#   '1cb03ad950bab1ca74b02500644ec1ba',
#   1325379736,
#   Decimal('40.773306000000000'),
#   Decimal('-92.821257000000000'),
#   0),
#  (85,
#   datetime.datetime(2019, 1, 1, 1, 2, 53),
#   571365235126,
#   'fraud_VonRueden Group',
#   'grocery_net',
#   Decimal('89.35'),
#   'Barbara',
#   'Taylor',
#   'F',
#   '0069 Robin Brooks Apt. 695',
#   'Elberta',
#   'MI',
#   49628,
#   Decimal('44.599500000000000'),
#   Decimal('-86.214100000000000'),
#   372,
#   'Exhibitions officer, museum,gallery',
#   datetime.date(1995, 7, 12),
#   'bce01a6ae8b8c6227cd4f1de751c017c',
#   1325379773,
#   Decimal('44.630758000000000'),
#   Decimal('-87.123893999999990'),
#   0),
#  (86,
#   datetime.datetime(2019, 1, 1, 1, 4, 48),
#   3518758680062249,
#   'fraud_Vandervort-Funk',
#   'grocery_pos',
#   Decimal('50.68'),
#   'Antonio',
#   'Koch',
#   'M',
#   '8738 Richard Brooks',
#   'Moab',
#   'UT',
#   84532,
#   Decimal('38.567700000000000'),
#   Decimal('-109.527100000000000'),
#   9772,
#   'Location manager',
#   datetime.date(1989, 11, 24),
#   '61861370b5c31b9c00fd949124944d7a',
#   1325379888,
#   Decimal('38.482541000000000'),
#   Decimal('-108.853856000000000'),
#   0),
#  (87,
#   datetime.datetime(2019, 1, 1, 1, 6, 6),
#   5456776410929288,
#   'fraud_Bernhard Inc',
#   'gas_transport',
#   Decimal('64.47'),
#   'Taylor',
#   'Khan',
#   'F',
#   '658 Diane Glen Apt. 677',
#   'North Washington',
#   'PA',
#   16048,
#   Decimal('41.047200000000000'),
#   Decimal('-79.808900000000000'),
#   139,
#   'Patent attorney',
#   datetime.date(1954, 5, 25),
#   '93953aab1a46beb5d65c8ab368a3f860',
#   1325379966,
#   Decimal('40.068764000000000'),
#   Decimal('-79.826882000000000'),
#   0),
#  (88,
#   datetime.datetime(2019, 1, 1, 1, 6, 22),
#   3577578023716568,
#   'fraud_Morissette, Weber and Wiegand',
#   'grocery_net',
#   Decimal('63.58'),
#   'Debbie',
#   'Hughes',
#   'F',
#   '0182 Owens Burgs Suite 480',
#   'Diamond',
#   'OH',
#   44412,
#   Decimal('41.093500000000000'),
#   Decimal('-81.042500000000000'),
#   2644,
#   'Engineer, biomedical',
#   datetime.date(1983, 8, 25),
#   '0189da32192f942196b01f50bcebeac8',
#   1325379982,
#   Decimal('41.813600000000000'),
#   Decimal('-81.230769999999990'),
#   0),
#  (89,
#   datetime.datetime(2019, 1, 1, 1, 8, 31),
#   213112402583773,
#   'fraud_Brekke and Sons',
#   'gas_transport',
#   Decimal('81.85'),
#   'Ana',
#   'Howell',
#   'F',
#   '4664 Sanchez Common Suite 930',
#   'Bradley',
#   'SC',
#   29819,
#   Decimal('34.032600000000000'),
#   Decimal('-82.202700000000000'),
#   1523,
#   'Research scientist (physical sciences)',
#   datetime.date(1984, 6, 3),
#   '4e2abdbd30c0353eeddf16650e1fc46b',
#   1325380111,
#   Decimal('33.828472999999995'),
#   Decimal('-81.642924000000000'),
#   0),
#  (90,
#   datetime.datetime(2019, 1, 1, 1, 9, 22),
#   3592325941359225,
#   'fraud_Mraz-Herzog',
#   'gas_transport',
#   Decimal('59.70'),
#   'Ashley',
#   'Robinson',
#   'F',
#   '1007 Colton Forks',
#   'Hopewell',
#   'VA',
#   23860,
#   Decimal('37.287600000000000'),
#   Decimal('-77.295000000000000'),
#   31970,
#   'Purchasing manager',
#   datetime.date(1935, 8, 15),
#   '9431e17d0ed2ec210587c4085d4c6887',
#   1325380162,
#   Decimal('36.962777000000000'),
#   Decimal('-77.640054000000000'),
#   0),
#  (91,
#   datetime.datetime(2019, 1, 1, 1, 9, 41),
#   4683520018489354,
#   'fraud_Ledner-Pfannerstill',
#   'gas_transport',
#   Decimal('90.54'),
#   'Charles',
#   'Carrillo',
#   'M',
#   '17547 Stephen Turnpike Apt. 846',
#   'Hawthorne',
#   'CA',
#   90250,
#   Decimal('33.914300000000000'),
#   Decimal('-118.349300000000000'),
#   93193,
#   'Editor, magazine features',
#   datetime.date(1995, 4, 19),
#   '295b782f9fa48f76f508179ec6412f9d',
#   1325380181,
#   Decimal('32.990285000000000'),
#   Decimal('-117.836803000000000'),
#   0),
#  (92,
#   datetime.datetime(2019, 1, 1, 1, 9, 57),
#   3502088871723054,
#   'fraud_Padberg-Welch',
#   'grocery_pos',
#   Decimal('50.57'),
#   'Scott',
#   'Martin',
#   'M',
#   '31472 Cody Place Suite 740',
#   'Kensington',
#   'MD',
#   20895,
#   Decimal('39.029800000000000'),
#   Decimal('-77.079300000000000'),
#   19054,
#   'Operations geologist',
#   datetime.date(1976, 9, 8),
#   '0cf233c92827db6083d311379ad67d46',
#   1325380197,
#   Decimal('38.394608000000005'),
#   Decimal('-76.437916000000000'),
#   0),
#  (93,
#   datetime.datetime(2019, 1, 1, 1, 9, 57),
#   180048185037117,
#   'fraud_Rippin, Kub and Mann',
#   'misc_net',
#   Decimal('3.79'),
#   'Mary',
#   'Wall',
#   'F',
#   '2481 Mills Lock',
#   'Plainfield',
#   'NJ',
#   7060,
#   Decimal('40.615200000000000'),
#   Decimal('-74.415000000000000'),
#   71485,
#   'Leisure centre manager',
#   datetime.date(1974, 7, 19),
#   '7c63dd07b14aac7dc99f4587d83dd599',
#   1325380197,
#   Decimal('40.813669000000000'),
#   Decimal('-75.283465000000000'),
#   0),
#  (94,
#   datetime.datetime(2019, 1, 1, 1, 10, 16),
#   6511349151405438,
#   'fraud_Kutch-Hegmann',
#   'grocery_net',
#   Decimal('54.54'),
#   'Robert',
#   'Nguyen',
#   'M',
#   '74835 Garner Point',
#   'Ruth',
#   'NV',
#   89319,
#   Decimal('39.342600000000000'),
#   Decimal('-114.885900000000000'),
#   450,
#   'Interpreter',
#   datetime.date(1946, 8, 24),
#   '2d441ff99c98107300207fdfc6dc71f0',
#   1325380216,
#   Decimal('38.693220000000000'),
#   Decimal('-115.875990000000000'),
#   0),
#  (95,
#   datetime.datetime(2019, 1, 1, 1, 11, 2),
#   4198470814557,
#   'fraud_Corwin-Gorczany',
#   'misc_net',
#   Decimal('3.35'),
#   'Christie',
#   'Williamson',
#   'F',
#   '519 Jerry Views',
#   'Avoca',
#   'IA',
#   51521,
#   Decimal('41.476800000000000'),
#   Decimal('-95.350900000000000'),
#   2036,
#   'Engineering geologist',
#   datetime.date(1971, 8, 20),
#   '054e43b7ffbe6f2315c2ef123f2da0c0',
#   1325380262,
#   Decimal('41.907592000000000'),
#   Decimal('-95.809232000000000'),
#   0),
#  (96,
#   datetime.datetime(2019, 1, 1, 1, 14, 11),
#   4423489490781412,
#   'fraud_Huels-Nolan',
#   'gas_transport',
#   Decimal('50.61'),
#   'Christopher',
#   'Ortega',
#   'M',
#   '5045 Emily Wall',
#   'Princeton',
#   'IA',
#   52768,
#   Decimal('41.685800000000000'),
#   Decimal('-90.370600000000000'),
#   1426,
#   'Agricultural consultant',
#   datetime.date(1957, 3, 6),
#   'a76f5e9735622f062eb663f06c169a94',
#   1325380451,
#   Decimal('41.027284000000000'),
#   Decimal('-89.416172000000000'),
#   0),
#  (97,
#   datetime.datetime(2019, 1, 1, 1, 14, 11),
#   3518234918950662,
#   'fraud_Jaskolski-Dibbert',
#   'grocery_net',
#   Decimal('50.74'),
#   'Barbara',
#   'Lowe',
#   'F',
#   '67210 Lori Creek',
#   'Sherman',
#   'TX',
#   75092,
#   Decimal('33.637200000000000'),
#   Decimal('-96.618400000000000'),
#   46563,
#   'Systems developer',
#   datetime.date(1970, 9, 11),
#   '8ba96beff66354e33f9fe96051a9a4a3',
#   1325380451,
#   Decimal('34.266941000000000'),
#   Decimal('-96.709668000000000'),
#   0),
#  (98,
#   datetime.datetime(2019, 1, 1, 1, 14, 55),
#   6593250708747804,
#   'fraud_DuBuque LLC',
#   'grocery_pos',
#   Decimal('186.73'),
#   'Melissa',
#   'Meza',
#   'F',
#   '244 Abbott Parkway',
#   'Loxahatchee',
#   'FL',
#   33470,
#   Decimal('26.738300000000000'),
#   Decimal('-80.276000000000010'),
#   26551,
#   'Paramedic',
#   datetime.date(1977, 1, 4),
#   '73e0bef38dd11227990b0e4e466d3706',
#   1325380495,
#   Decimal('27.610009000000000'),
#   Decimal('-79.498110000000000'),
#   0),
#  (99,
#   datetime.datetime(2019, 1, 1, 1, 15, 1),
#   6011492816282597,
#   'fraud_Kutch-Hegmann',
#   'grocery_net',
#   Decimal('39.95'),
#   'Gary',
#   'Barnes',
#   'M',
#   '2970 Flores Brooks',
#   'Smackover',
#   'AR',
#   71762,
#   Decimal('33.339800000000000'),
#   Decimal('-92.744200000000000'),
#   2501,
#   'Financial adviser',
#   datetime.date(1986, 6, 11),
#   'f487762b6cebc5a18abcfcb90b644c01',
#   1325380501,
#   Decimal('33.651123000000000'),
#   Decimal('-91.902918000000000'),
#   0),
#  (100,
#   datetime.datetime(2019, 1, 1, 1, 16, 52),
#   6593250708747804,
#   'fraud_Brekke and Sons',
#   'gas_transport',
#   Decimal('55.18'),
#   'Melissa',
#   'Meza',
#   'F',
#   '244 Abbott Parkway',
# ...
#   '96908438bcbf6b7dd750877d8f217f4e',
#   1325704138,
#   Decimal('45.629538000000000'),
#   Decimal('-118.712898000000000'),
#   0),
#  (965,
#   datetime.datetime(2019, 1, 1, 12, 18, 22),
#   36153880429415,
#   'fraud_Berge, Kautzer and Harris',
#   'personal_care',
#   Decimal('5.97'),
#   'Erik',
#   'Stevens',
#   'M',
#   '84033 Pitts Overpass',
#   'Lakeland',
#   'FL',
#   33809,
#   Decimal('28.176200000000000'),
#   Decimal('-81.959100000000000'),
#   237282,
#   'Plant breeder,geneticist',
#   datetime.date(1949, 10, 13),
#   'c04350fab991cc8a7ee2970625702c76',
#   1325420302,
#   Decimal('27.504831000000000'),
#   Decimal('-81.125720000000000'),
#   0),
#  (966,
#   datetime.datetime(2019, 1, 1, 12, 18, 32),
#   378278619832195,
#   'fraud_Hammes-Beatty',
#   'kids_pets',
#   Decimal('78.55'),
#   'Mary',
#   'Mcintyre',
#   'F',
#   '77921 Costa Villages',
#   'Eugene',
#   'OR',
#   97403,
#   Decimal('44.038500000000000'),
#   Decimal('-123.061400000000000'),
#   191096,
#   'Scientist, physiological',
#   datetime.date(1964, 4, 6),
#   '0681c9e2a48735a47fccf0bed805d52f',
#   1325420312,
#   Decimal('44.398931000000000'),
#   Decimal('-122.136405000000000'),
#   0),
#  (967,
#   datetime.datetime(2019, 1, 1, 12, 18, 35),
#   6592861994408652,
#   'fraud_Hilpert-Conroy',
#   'kids_pets',
#   Decimal('47.67'),
#   'Ashley',
#   'Whitehead',
#   'F',
#   '58188 Madison Meadow Apt. 949',
#   'Cowlesville',
#   'NY',
#   14037,
#   Decimal('42.811200000000000'),
#   Decimal('-78.448100000000000'),
#   1166,
#   'Colour technologist',
#   datetime.date(1983, 6, 12),
#   '223d4dea23f453040875faabbf2660c4',
#   1325420315,
#   Decimal('43.770821000000005'),
#   Decimal('-78.115454000000000'),
#   0),
#  (968,
#   datetime.datetime(2019, 1, 1, 12, 18, 39),
#   4265776278887457,
#   'fraud_Gulgowski LLC',
#   'home',
#   Decimal('48.23'),
#   'Christine',
#   'Best',
#   'F',
#   '68248 Deanna Land',
#   'Enola',
#   'AR',
#   72047,
#   Decimal('35.208700000000000'),
#   Decimal('-92.212300000000000'),
#   969,
#   'Physicist, medical',
#   datetime.date(1954, 1, 5),
#   '2af1152e1cb4180b231f4a5dc069b410',
#   1325420319,
#   Decimal('35.255428000000000'),
#   Decimal('-92.675387000000000'),
#   0),
#  (969,
#   datetime.datetime(2019, 1, 1, 12, 19, 29),
#   3525590521269779,
#   'fraud_Schuppe, Nolan and Hoeger',
#   'shopping_pos',
#   Decimal('8.16'),
#   'Scott',
#   'Fuller',
#   'M',
#   '861 Karen Common',
#   'Haw River',
#   'NC',
#   27258,
#   Decimal('36.042400000000000'),
#   Decimal('-79.324200000000000'),
#   6006,
#   'Paramedic',
#   datetime.date(1984, 7, 20),
#   '5d74e84280d8c640971b169c209edffc',
#   1325420369,
#   Decimal('36.874665000000000'),
#   Decimal('-79.936631999999990'),
#   0),
#  (970,
#   datetime.datetime(2019, 1, 1, 12, 20, 32),
#   4623560839669,
#   'fraud_Cormier, Stracke and Thiel',
#   'entertainment',
#   Decimal('37.23'),
#   'Vincent',
#   'Waller',
#   'M',
#   '9379 Vanessa Run Apt. 400',
#   'Lohrville',
#   'IA',
#   51453,
#   Decimal('42.261900000000000'),
#   Decimal('-94.556600000000000'),
#   695,
#   'Administrator',
#   datetime.date(1954, 7, 15),
#   '3df341c535cad9f4ff8899883f3c0280',
#   1325420432,
#   Decimal('41.868955000000000'),
#   Decimal('-94.169401000000000'),
#   0),
#  (971,
#   datetime.datetime(2019, 1, 1, 12, 20, 52),
#   630424987505,
#   'fraud_Pollich LLC',
#   'home',
#   Decimal('50.76'),
#   'Jennifer',
#   'Black',
#   'F',
#   '2870 Bean Terrace Apt. 756',
#   'Thomas',
#   'WV',
#   26292,
#   Decimal('39.150500000000000'),
#   Decimal('-79.503000000000000'),
#   836,
#   'Forensic psychologist',
#   datetime.date(1981, 8, 29),
#   '9dbd3e453520b220e7212a665e1f7445',
#   1325420452,
#   Decimal('38.412664000000000'),
#   Decimal('-79.018129000000000'),
#   0),
#  (972,
#   datetime.datetime(2019, 1, 1, 12, 24, 18),
#   4761403817546679245,
#   'fraud_Bernier and Sons',
#   'kids_pets',
#   Decimal('166.74'),
#   'Diana',
#   'Jacobs',
#   'F',
#   '69608 Perez Mountain Apt. 006',
#   'Viola',
#   'AR',
#   72583,
#   Decimal('36.392400000000000'),
#   Decimal('-91.993200000000000'),
#   1679,
#   'Psychiatric nurse',
#   datetime.date(1986, 5, 2),
#   'dceba15fe2cb6b7003e8ac59b068b9c6',
#   1325420658,
#   Decimal('36.455184000000000'),
#   Decimal('-92.150945000000000'),
#   0),
#  (973,
#   datetime.datetime(2019, 1, 1, 12, 24, 50),
#   4635330563105903,
#   'fraud_Wilkinson PLC',
#   'kids_pets',
#   Decimal('153.08'),
#   'Christina',
#   'Rose',
#   'F',
#   '1984 Taylor Island Suite 836',
#   'Falls Church',
#   'VA',
#   22046,
#   Decimal('38.885600000000000'),
#   Decimal('-77.180200000000000'),
#   116155,
#   'Chartered accountant',
#   datetime.date(1983, 7, 10),
#   'e37f3ffe71a7031270be430ee6eac6f7',
#   1325420690,
#   Decimal('39.848967000000000'),
#   Decimal('-77.024924000000000'),
#   0),
#  (974,
#   datetime.datetime(2019, 1, 1, 12, 26, 42),
#   4653879239169997,
#   'fraud_Kling-Ernser',
#   'entertainment',
#   Decimal('6.26'),
#   'Monica',
#   'Tucker',
#   'F',
#   '302 Christina Islands',
#   'Smiths Grove',
#   'KY',
#   42171,
#   Decimal('37.058100000000000'),
#   Decimal('-86.193800000000000'),
#   6841,
#   'Therapist, sports',
#   datetime.date(1999, 6, 6),
#   'aca332cf653fa9358ea7024f964e6f3f',
#   1325420802,
#   Decimal('36.316531000000000'),
#   Decimal('-85.956486000000000'),
#   0),
#  (975,
#   datetime.datetime(2019, 1, 1, 12, 26, 57),
#   30487648872433,
#   'fraud_Bednar Inc',
#   'travel',
#   Decimal('5.09'),
#   'Stephanie',
#   'Crane',
#   'F',
#   '144 Martinez Curve',
#   'Central',
#   'IN',
#   47110,
#   Decimal('38.097000000000000'),
#   Decimal('-86.172300000000000'),
#   350,
#   'Counsellor',
#   datetime.date(1955, 1, 5),
#   'fe537bb2ec779ae3a337d50a3c7a7dfd',
#   1325420817,
#   Decimal('37.653705000000000'),
#   Decimal('-86.315351000000000'),
#   0),
#  (976,
#   datetime.datetime(2019, 1, 1, 12, 27, 15),
#   3553629419254918,
#   'fraud_Reichert, Rowe and Mraz',
#   'shopping_net',
#   Decimal('8.38'),
#   'Sharon',
#   'Johnson',
#   'F',
#   '7202 Jeffrey Mills',
#   'Conway',
#   'WA',
#   98238,
#   Decimal('48.340000000000000'),
#   Decimal('-122.345600000000000'),
#   85,
#   'Research officer, political party',
#   datetime.date(1984, 9, 1),
#   '75971e5cf0d65c6410d8d9df1eeb626a',
#   1325420835,
#   Decimal('47.841849000000000'),
#   Decimal('-122.904667000000000'),
#   0),
#  (977,
#   datetime.datetime(2019, 1, 1, 12, 28, 3),
#   3551217896304745,
#   "fraud_O'Connell, Botsford and Hand",
#   'home',
#   Decimal('126.15'),
#   'Sara',
#   'Harris',
#   'F',
#   '597 Jenny Ford Apt. 543',
#   'Tupper Lake',
#   'NY',
#   12986,
#   Decimal('44.232000000000000'),
#   Decimal('-74.490500000000000'),
#   6120,
#   'Chartered loss adjuster',
#   datetime.date(1976, 10, 9),
#   '5a1fd9fc525d50c1512dba3b8fb57957',
#   1325420883,
#   Decimal('44.513683000000000'),
#   Decimal('-74.923788000000000'),
#   0),
#  (978,
#   datetime.datetime(2019, 1, 1, 12, 28, 25),
#   373905417449658,
#   'fraud_Little-Gleichner',
#   'travel',
#   Decimal('7.67'),
#   'Sarah',
#   'Bishop',
#   'F',
#   '554 Mcdonald Valley Apt. 539',
#   'Meridian',
#   'TX',
#   76665,
#   Decimal('31.929000000000000'),
#   Decimal('-97.644300000000000'),
#   2526,
#   'Phytotherapist',
#   datetime.date(1970, 11, 12),
#   '87a865a79a58d3abc3498c7841817c98',
#   1325420905,
#   Decimal('32.389161000000000'),
#   Decimal('-96.994764000000000'),
#   0),
#  (979,
#   datetime.datetime(2019, 1, 1, 12, 28, 41),
#   4452366298769043,
#   'fraud_Champlin and Sons',
#   'home',
#   Decimal('19.12'),
#   'Linda',
#   'Davis',
#   'F',
#   '6602 Ortiz Pine Apt. 179',
#   'Blooming Grove',
#   'TX',
#   76626,
#   Decimal('32.075800000000000'),
#   Decimal('-96.701000000000000'),
#   1563,
#   'Financial adviser',
#   datetime.date(1978, 3, 4),
#   '740ba21b3f6dac605752b84ef73f56e4',
#   1325420921,
#   Decimal('32.556114000000000'),
#   Decimal('-96.608229000000000'),
#   0),
#  (980,
#   datetime.datetime(2019, 1, 1, 12, 28, 54),
#   4951647200979051,
#   'fraud_Hoppe-Parisian',
#   'kids_pets',
#   Decimal('77.89'),
#   'Kimberly',
#   'Miller',
#   'F',
#   '75533 Tamara Valleys',
#   'Logan',
#   'IL',
#   62856,
#   Decimal('37.994300000000000'),
#   Decimal('-88.941700000000000'),
#   324,
#   'Scientist, research (physical sciences)',
#   datetime.date(1976, 6, 15),
#   'fc3e6cd1be3853f5bcd8fda06df5a7e8',
#   1325420934,
#   Decimal('38.789938000000000'),
#   Decimal('-89.875102000000000'),
#   0),
#  (981,
#   datetime.datetime(2019, 1, 1, 12, 29, 30),
#   3576021480694169,
#   'fraud_Hickle Group',
#   'shopping_pos',
#   Decimal('9.19'),
#   'Dawn',
#   'Gray',
#   'F',
#   '9486 Joel Common Suite 554',
#   'Topeka',
#   'KS',
#   66618,
#   Decimal('39.132900000000000'),
#   Decimal('-95.702300000000000'),
#   163415,
#   'Secondary school teacher',
#   datetime.date(2004, 12, 30),
#   '91561e65399053586ad098022374ec45',
#   1325420970,
#   Decimal('38.949619000000000'),
#   Decimal('-95.471502000000000'),
#   0),
#  (982,
#   datetime.datetime(2019, 1, 1, 12, 30, 29),
#   4025612008285111,
#   'fraud_Schuppe LLC',
#   'entertainment',
#   Decimal('1.39'),
#   'Krystal',
#   'Key',
#   'F',
#   '23142 Montoya Island Apt. 742',
#   'Corsica',
#   'PA',
#   15829,
#   Decimal('41.176200000000000'),
#   Decimal('-79.197600000000000'),
#   1274,
#   'Maintenance engineer',
#   datetime.date(1949, 3, 20),
#   'f73411d6097ddcf5d1e45786bf55023e',
#   1325421029,
#   Decimal('41.078812000000000'),
#   Decimal('-78.670385000000000'),
#   0),
#  (983,
#   datetime.datetime(2019, 1, 1, 12, 30, 32),
#   6011999606625827,
#   'fraud_Emmerich-Rau',
#   'personal_care',
#   Decimal('7.93'),
#   'Ronald',
#   'Carson',
#   'M',
#   '870 Rocha Drive',
#   'Harrington Park',
#   'NJ',
#   7640,
#   Decimal('40.991800000000000'),
#   Decimal('-73.980000000000000'),
#   4664,
#   'Radiographer, diagnostic',
#   datetime.date(1965, 6, 30),
#   '07a01c46cfb0409dc45ec245ef1a26d2',
#   1325421032,
#   Decimal('40.169799000000000'),
#   Decimal('-74.569352000000000'),
#   0),
#  (984,
#   datetime.datetime(2019, 1, 1, 12, 31, 9),
#   60490596305,
#   'fraud_Beier LLC',
#   'entertainment',
#   Decimal('87.07'),
#   'Karen',
#   'Johnson',
#   'F',
#   '4349 Anna Flat Suite 214',
#   'Haynes',
#   'AR',
#   72341,
#   Decimal('34.883800000000000'),
#   Decimal('-90.766600000000000'),
#   222,
#   'Programmer, applications',
#   datetime.date(1963, 5, 19),
#   'f5bd9046ca1a4bfc4b92fc51f9a341be',
#   1325421069,
#   Decimal('34.446626000000000'),
#   Decimal('-90.840089000000000'),
#   0),
#  (985,
#   datetime.datetime(2019, 1, 1, 12, 31, 20),
#   3598014571045296,
#   'fraud_Champlin-Casper',
#   'home',
#   Decimal('30.24'),
#   'Lisa',
#   'Clark',
#   'F',
#   '07943 Davis River',
#   'Grimesland',
#   'NC',
#   27837,
#   Decimal('35.558000000000000'),
#   Decimal('-77.256600000000000'),
#   5903,
#   'Manufacturing systems engineer',
#   datetime.date(1993, 10, 7),
#   'a881d5d571e40cb4c1e9d0d9911e44d8',
#   1325421080,
#   Decimal('36.321630000000000'),
#   Decimal('-77.667004000000000'),
#   0),
#  (986,
#   datetime.datetime(2019, 1, 1, 12, 31, 30),
#   4561546772499,
#   'fraud_Hills-Witting',
#   'shopping_net',
#   Decimal('3.27'),
#   'Daniel',
#   'Briggs',
#   'M',
#   '7118 Jessica Unions Apt. 789',
#   'Moriarty',
#   'NM',
#   87035,
#   Decimal('34.988900000000000'),
#   Decimal('-106.060900000000000'),
#   7268,
#   'Therapist, art',
#   datetime.date(1988, 8, 4),
#   '4c5ea52c510bed81758879cb8bf7adb0',
#   1325421090,
#   Decimal('35.863489000000000'),
#   Decimal('-105.606809000000000'),
#   0),
#  (987,
#   datetime.datetime(2019, 1, 1, 12, 32, 2),
#   3502088871723054,
#   'fraud_Gerhold LLC',
#   'home',
#   Decimal('104.92'),
#   'Scott',
#   'Martin',
#   'M',
#   '31472 Cody Place Suite 740',
#   'Kensington',
#   'MD',
#   20895,
#   Decimal('39.029800000000000'),
#   Decimal('-77.079300000000000'),
#   19054,
#   'Operations geologist',
#   datetime.date(1976, 9, 8),
#   '658d63401a38e32c7fc20ba44ce9cea0',
#   1325421122,
#   Decimal('39.529375000000000'),
#   Decimal('-77.560792000000000'),
#   0),
#  (988,
#   datetime.datetime(2019, 1, 1, 12, 32, 55),
#   30551643947183,
#   'fraud_Renner Ltd',
#   'home',
#   Decimal('151.34'),
#   'Morgan',
#   'Smith',
#   'F',
#   '1441 Bradley Place',
#   'Grover',
#   'NC',
#   28073,
#   Decimal('35.183600000000000'),
#   Decimal('-81.455200000000000'),
#   5621,
#   'Toxicologist',
#   datetime.date(1973, 11, 14),
#   '271dcd4b999af1960c0e05ce93023375',
#   1325421175,
#   Decimal('34.662994000000000'),
#   Decimal('-81.083259000000000'),
#   0),
#  (989,
#   datetime.datetime(2019, 1, 1, 12, 33, 31),
#   502049568400,
#   'fraud_Koss, McLaughlin and Mayer',
#   'food_dining',
#   Decimal('16.96'),
#   'Daniel',
#   'Melton',
#   'M',
#   '6157 Nichols Mews',
#   'Marion',
#   'CT',
#   6444,
#   Decimal('41.791800000000000'),
#   Decimal('-72.718800000000000'),
#   370,
#   'Health service manager',
#   datetime.date(1962, 2, 13),
#   '9758286fed653eba42871f870d080e81',
#   1325421211,
#   Decimal('42.630707000000000'),
#   Decimal('-72.135343000000000'),
#   0),
#  (990,
#   datetime.datetime(2019, 1, 1, 12, 33, 50),
#   2229378226512508,
#   'fraud_Gaylord-Powlowski',
#   'home',
#   Decimal('83.06'),
#   'Thomas',
#   'Hale',
#   'M',
#   '949 Smith Parkway',
#   'Cazenovia',
#   'WI',
#   53924,
#   Decimal('43.498700000000000'),
#   Decimal('-90.279600000000000'),
#   1360,
#   'Occupational hygienist',
#   datetime.date(1984, 11, 6),
#   '4f1eed06d0bf56877ac5b21d1ffd39e0',
#   1325421230,
#   Decimal('43.016205000000000'),
#   Decimal('-90.796644000000000'),
#   0),
#  (991,
#   datetime.datetime(2019, 1, 1, 12, 35, 50),
#   4996263498048679,
#   'fraud_Prosacco, Kreiger and Kovacek',
#   'home',
#   Decimal('3.13'),
#   'Kendra',
#   'King',
#   'F',
#   '154 Hernandez Keys',
#   'Smith River',
#   'CA',
#   95567,
#   Decimal('41.940400000000000'),
#   Decimal('-124.158700000000000'),
#   1930,
#   'Web designer',
#   datetime.date(1983, 6, 13),
#   '6e8e6642a7745cc089a12016bf5c3f10',
#   1325421350,
#   Decimal('41.918079000000000'),
#   Decimal('-123.524131000000000'),
#   0),
#  (992,
#   datetime.datetime(2019, 1, 1, 12, 37, 48),
#   3545109339866548,
#   'fraud_Eichmann-Kilback',
#   'home',
#   Decimal('114.11'),
#   'Keith',
#   'Sanders',
#   'M',
#   '8030 Beck Motorway',
#   'Moorhead',
#   'MS',
#   38761,
#   Decimal('33.478300000000000'),
#   Decimal('-90.514200000000000'),
#   2870,
#   'Chartered public finance accountant',
#   datetime.date(1999, 3, 5),
#   'c81abf0e3ff96e25e1cc8fbc8e896c83',
#   1325421468,
#   Decimal('33.908128999999995'),
#   Decimal('-89.693832000000000'),
#   0),
#  (993,
#   datetime.datetime(2019, 1, 1, 12, 38, 21),
#   30234966027947,
#   "fraud_O'Hara-Wilderman",
#   'food_dining',
#   Decimal('105.47'),
#   'Matthew',
#   'Lambert',
#   'M',
#   '7188 Melissa Crest Apt. 151',
#   'New Holstein',
#   'WI',
#   53061,
#   Decimal('43.944600000000000'),
#   Decimal('-88.091100000000000'),
#   5196,
#   'Child psychotherapist',
#   datetime.date(1978, 1, 22),
#   '1bf8466e33eee01ec62be529a1866b77',
#   1325421501,
#   Decimal('44.215230000000000'),
#   Decimal('-88.792643000000000'),
#   0),
#  (994,
#   datetime.datetime(2019, 1, 1, 12, 38, 37),
#   4467456915153312231,
#   'fraud_Terry Ltd',
#   'home',
#   Decimal('27.34'),
#   'Rita',
#   'Myers',
#   'F',
#   '75703 Hernandez Corner Suite 348',
#   'Tampa',
#   'FL',
#   33620,
#   Decimal('28.060000000000000'),
#   Decimal('-82.407900000000000'),
#   717255,
#   'Waste management officer',
#   datetime.date(1966, 9, 16),
#   '1bf15a4132022bcba514ebfaafd47c39',
#   1325421517,
#   Decimal('28.095758000000000'),
#   Decimal('-82.206296999999990'),
#   0),
#  (995,
#   datetime.datetime(2019, 1, 1, 12, 38, 38),
#   6592243974328236,
#   'fraud_Beier and Sons',
#   'home',
#   Decimal('43.73'),
#   'Philip',
#   'Hart',
#   'M',
#   '97405 Vazquez Plains',
#   'Montgomery',
#   'AL',
#   36111,
#   Decimal('32.337400000000000'),
#   Decimal('-86.271500000000000'),
#   214703,
#   'Chemist, analytical',
#   datetime.date(1994, 10, 7),
#   'c5f6d4b1ac5f1caba326608f0cf293fa',
#   1325421518,
#   Decimal('32.744104000000000'),
#   Decimal('-87.025559000000000'),
#   0),
#  (996,
#   datetime.datetime(2019, 1, 1, 12, 39, 18),
#   4653879239169997,
#   'fraud_Pouros-Haag',
#   'shopping_pos',
#   Decimal('7.98'),
#   'Monica',
#   'Tucker',
#   'F',
#   '302 Christina Islands',
#   'Smiths Grove',
#   'KY',
#   42171,
#   Decimal('37.058100000000000'),
#   Decimal('-86.193800000000000'),
#   6841,
#   'Therapist, sports',
#   datetime.date(1999, 6, 6),
#   'bc909cd211ddb4d3f6511abee1423324',
#   1325421558,
#   Decimal('37.787593000000000'),
#   Decimal('-85.931895000000000'),
#   0),
#  (997,
#   datetime.datetime(2019, 1, 1, 12, 39, 27),
#   38588538868506,
#   "fraud_O'Keefe-Wisoky",
#   'food_dining',
#   Decimal('2.86'),
#   'Jacqueline',
#   'Curry',
#   'F',
#   '3047 Jeff Place',
#   'Marathon',
#   'TX',
#   79842,
#   Decimal('30.188600000000000'),
#   Decimal('-103.221400000000000'),
#   498,
#   'Lexicographer',
#   datetime.date(1990, 11, 23),
#   'c882715837e35bc8a69be786678ea147',
#   1325421567,
#   Decimal('29.273326000000000'),
#   Decimal('-104.007592000000000'),
#   0),
#  ...]

# %%
df = pd.DataFrame(data, columns=["credit_id", "trans_date_time", "cc_num",
                                "merchant_name", "category_merchant", "amt",
                                "first_name", "last_name", "gender", "street_address",
                                "city", "us_state", "zip_code", "lat", "long",
                                "city_pop", "job", "dob", "trans_num",
                                "unix_time", "merch_lat", "merch_long",
                                "is_fraud"])

# %%
df
# Out:
#          credit_id     trans_date_time               cc_num  \
# 0                1 2019-01-01 00:00:44         630423337322
# 1                2 2019-01-01 00:00:51       38859492057661
# 2                3 2019-01-01 00:01:16     3534093764340240
# 3                4 2019-01-01 00:03:06      375534208663984
# 4                5 2019-01-01 00:04:08     4767265376804500
# ...            ...                 ...                  ...
# 1296669    1296670 2020-06-21 12:12:08       30263540414123
# 1296670    1296671 2020-06-21 12:12:19     6011149206456997
# 1296671    1296672 2020-06-21 12:12:32     3514865930894695
# 1296672    1296673 2020-06-21 12:13:36     2720012583106919
# 1296673    1296674 2020-06-21 12:13:37  4292902571056973207
#
#                                merchant_name category_merchant     amt  \
# 0            fraud_Heller, Gutmann and Zieme       grocery_pos  107.23
# 1                       fraud_Lind-Buckridge     entertainment  220.11
# 2         fraud_Kutch, Hermiston and Farrell     gas_transport   45.00
# 3                        fraud_Keeling-Crist          misc_pos   41.96
# 4           fraud_Stroman, Hudson and Erdman     gas_transport   94.63
# ...                                      ...               ...     ...
# 1296669                    fraud_Reichel Inc     entertainment   15.56
# 1296670             fraud_Abernathy and Sons       food_dining   51.70
# 1296671                 fraud_Stiedemann Ltd       food_dining  105.93
# 1296672  fraud_Reinger, Weissnat and Strosin       food_dining   74.90
# 1296673  fraud_Langosh, Wintheiser and Hyatt       food_dining    4.30
#
#           first_name  last_name gender                 street_address  ...  \
# 0          Stephanie       Gill      F   43039 Riley Greens Suite 393  ...
# 1             Edward    Sanchez      M       594 White Dale Suite 530  ...
# 2             Jeremy      White      M    9443 Cynthia Court Apt. 038  ...
# 3              Tyler     Garcia      M               408 Bradley Rest  ...
# 4           Jennifer     Conner      F              4655 David Island  ...
# ...              ...        ...    ...                            ...  ...
# 1296669         Erik  Patterson      M       162 Jessica Row Apt. 072  ...
# 1296670      Jeffrey      White      M  8617 Holmes Terrace Suite 651  ...
# 1296671  Christopher  Castaneda      M     1632 Cohen Drive Suite 639  ...
# 1296672       Joseph     Murray      M           42933 Ryan Underpass  ...
# 1296673      Jeffrey      Smith      M           135 Joseph Mountains  ...
#
#                         lat                  long  city_pop  \
# 0        48.887800000000000  -118.210500000000000       149
# 1        42.180800000000000  -112.262000000000000      4154
# 2        46.230600000000000  -112.113800000000000      1939
# 3        38.420700000000000   -79.462900000000000        99
# 4        40.375000000000000   -75.204500000000000      2158
# ...                     ...                   ...       ...
# 1296669  37.717500000000000  -112.477700000000000       258
# 1296670  39.266700000000000   -77.510100000000000       100
# 1296671  32.939600000000000  -105.818900000000000       899
# 1296672  43.352600000000000  -102.541100000000000      1126
# 1296673  45.843300000000000  -113.874800000000000       218
#
#                                        job         dob  \
# 0        Special educational needs teacher  1978-06-21
# 1              Nature conservation officer  1962-01-19
# 2                          Patent attorney  1967-01-12
# 3           Dance movement psychotherapist  1986-03-28
# 4                        Transport planner  1961-06-19
# ...                                    ...         ...
# 1296669                       Geoscientist  1961-11-24
# 1296670   Production assistant, television  1979-12-11
# 1296671                    Naval architect  1967-08-30
# 1296672              Volunteer coordinator  1980-08-18
# 1296673           Therapist, horticultural  1995-08-16
#
#                                 trans_num   unix_time           merch_lat  \
# 0        1f76529f8574734946361c461b024d99  1325376044  49.159047000000000
# 1        a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704000000000
# 2        6b849c168bdad6f867558c3793159a81  1325376076  47.034331000000000
# 3        a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999000000000
# 4        189a841a0a8ba03058526bcfe566aab5  1325376248  40.653382000000000
# ...                                   ...         ...                 ...
# 1296669  440b587732da4dc1a6395aba5fb41669  1371816728  36.841266000000000
# 1296670  278000d2e0d2277d1de2f890067dcc0a  1371816739  38.906881000000000
# 1296671  483f52fe67fabef353d552c1e662974c  1371816752  33.619513000000000
# 1296672  d667cdcbadaaed3da3f4020e83591c83  1371816816  42.788940000000000
# 1296673  8f7c8e4ab7f25875d753b422917c98c9  1371816817  46.565983000000000
#
#                    merch_long  is_fraud
# 0        -118.186462000000000         0
# 1        -112.154481000000000         0
# 2        -112.561071000000000         0
# 3         -78.632459000000000         0
# 4         -76.152667000000010         0
# ...                       ...       ...
# 1296669  -111.690764999999980         0
# 1296670   -78.246528000000000         0
# 1296671  -105.130529000000000         0
# 1296672  -103.241160000000000         0
# 1296673  -114.186110000000000         0
#
# [1296674 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['credit_id', 'trans_date_time', 'cc_num', 'merchant_name',
#        'category_merchant', 'amt', 'first_name', 'last_name', 'gender',
#        'street_address', 'city', 'us_state', 'zip_code', 'lat', 'long',
#        'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df.describe()
# Out:
#           credit_id        cc_num      zip_code      city_pop     unix_time  \
# count  1.296674e+06  1.296674e+06  1.296674e+06  1.296674e+06  1.296674e+06
# mean   6.483375e+05  4.171924e+17  4.880069e+04  8.882451e+04  1.349244e+09
# std    3.743177e+05  1.308807e+18  2.689323e+04  3.019565e+05  1.284127e+07
# min    1.000000e+00  6.041621e+10  1.257000e+03  2.300000e+01  1.325376e+09
# 25%    3.241692e+05  1.800429e+14  2.623700e+04  7.430000e+02  1.338751e+09
# 50%    6.483375e+05  3.521417e+15  4.817400e+04  2.456000e+03  1.349250e+09
# 75%    9.725058e+05  4.642255e+15  7.204200e+04  2.032800e+04  1.359385e+09
# max    1.296674e+06  4.992346e+18  9.978300e+04  2.906700e+06  1.371817e+09
#
#            is_fraud
# count  1.296674e+06
# mean   5.788656e-03
# std    7.586272e-02
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e+00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296674 entries, 0 to 1296673
# Data columns (total 23 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   credit_id          1296674 non-null  int64
#  1   trans_date_time    1296674 non-null  datetime64[ns]
#  2   cc_num             1296674 non-null  int64
#  3   merchant_name      1296674 non-null  object
#  4   category_merchant  1296674 non-null  object
#  5   amt                1296674 non-null  object
#  6   first_name         1296674 non-null  object
#  7   last_name          1296674 non-null  object
#  8   gender             1296674 non-null  object
#  9   street_address     1296674 non-null  object
#  10  city               1296674 non-null  object
#  11  us_state           1296674 non-null  object
#  12  zip_code           1296674 non-null  int64
#  13  lat                1296674 non-null  object
#  14  long               1296674 non-null  object
#  15  city_pop           1296674 non-null  int64
#  16  job                1296674 non-null  object
#  17  dob                1296674 non-null  object
#  18  trans_num          1296674 non-null  object
#  19  unix_time          1296674 non-null  int64
#  20  merch_lat          1296674 non-null  object
#  21  merch_long         1296674 non-null  object
#  22  is_fraud           1296674 non-null  int64
# dtypes: datetime64[ns](1), int64(6), object(16)
# memory usage: 227.5+ MB

# %%
df["trans_date_time"].unique().value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df["trans_date_time"].unique().value_counts()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
sns.heatmap(df.corr(), annot=True, cmap="winter")
# Out:
# <AxesSubplot:>

# %%
df["amt"] = df["amt"].astype(float)

# %%
df["amt"]
# Out:
# 0          107.23
# 1          220.11
# 2           45.00
# 3           41.96
# 4           94.63
#             ...
# 1296669     15.56
# 1296670     51.70
# 1296671    105.93
# 1296672     74.90
# 1296673      4.30
# Name: amt, Length: 1296674, dtype: float64

# %%
df.corr()
# Out:
#            credit_id    cc_num       amt  zip_code  city_pop  unix_time  \
# credit_id   1.000000  0.000385 -0.000252  0.000708 -0.001678   0.998971
# cc_num      0.000385  1.000000  0.001769  0.041459 -0.008991   0.000353
# amt        -0.000252  0.001769  1.000000  0.001843  0.005818  -0.000294
# zip_code    0.000708  0.041459  0.001843  1.000000  0.078467   0.000669
# city_pop   -0.001678 -0.008991  0.005818  0.078467  1.000000  -0.001714
# unix_time   0.998971  0.000353 -0.000294  0.000669 -0.001714   1.000000
# is_fraud   -0.004768 -0.000981  0.219404 -0.002162  0.002136  -0.005078
#
#            is_fraud
# credit_id -0.004768
# cc_num    -0.000981
# amt        0.219404
# zip_code  -0.002162
# city_pop   0.002136
# unix_time -0.005078
# is_fraud   1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap="winter")
# Out:
# <AxesSubplot:>

# %%
df["unix_time"]
# Out:
# 0          1325376044
# 1          1325376051
# 2          1325376076
# 3          1325376186
# 4          1325376248
#               ...
# 1296669    1371816728
# 1296670    1371816739
# 1296671    1371816752
# 1296672    1371816816
# 1296673    1371816817
# Name: unix_time, Length: 1296674, dtype: int64

# %%
df["credit_id"]
# Out:
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
#             ...
# 1296669    1296670
# 1296670    1296671
# 1296671    1296672
# 1296672    1296673
# 1296673    1296674
# Name: credit_id, Length: 1296674, dtype: int64
